# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
## Reading the 'articles.tsv' file as a pandas dataframe
PATH_IN = './data/'
fname = os.path.join(PATH_IN, 'wikispeedia_paths-and-graph/articles.tsv')
df_article = pd.read_csv(fname, sep = '\t', comment = '#', header = None, names = ['articles'],encoding = 'UTF-8')
df_article
# Out:
#                               articles
# 0     %C3%81ed%C3%A1n_mac_Gabr%C3%A1in
# 1                           %C3%85land
# 2                   %C3%89douard_Manet
# 3                            %C3%89ire
# 4           %C3%93engus_I_of_the_Picts
# ...                                ...
# 4599                           Zionism
# 4600                         Zirconium
# 4601                         Zoroaster
# 4602                      Zuid-Gelders
# 4603                              Zulu
#
# [4604 rows x 1 columns]

# %%
## record index and change index to articles names

df_article['num'] = df_article.index.copy(deep = True)
df_article.index = df_article['articles']
df_article
# Out:
#                                                           articles   num
# articles
# %C3%81ed%C3%A1n_mac_Gabr%C3%A1in  %C3%81ed%C3%A1n_mac_Gabr%C3%A1in     0
# %C3%85land                                              %C3%85land     1
# %C3%89douard_Manet                              %C3%89douard_Manet     2
# %C3%89ire                                                %C3%89ire     3
# %C3%93engus_I_of_the_Picts              %C3%93engus_I_of_the_Picts     4
# ...                                                            ...   ...
# Zionism                                                    Zionism  4599
# Zirconium                                                Zirconium  4600
# Zoroaster                                                Zoroaster  4601
# Zuid-Gelders                                          Zuid-Gelders  4602
# Zulu                                                          Zulu  4603
#
# [4604 rows x 2 columns]

# %%
## add withdraw '<'

df_article.loc['<'] = -1
df_article
# Out:
#                                                           articles   num
# articles
# %C3%81ed%C3%A1n_mac_Gabr%C3%A1in  %C3%81ed%C3%A1n_mac_Gabr%C3%A1in     0
# %C3%85land                                              %C3%85land     1
# %C3%89douard_Manet                              %C3%89douard_Manet     2
# %C3%89ire                                                %C3%89ire     3
# %C3%93engus_I_of_the_Picts              %C3%93engus_I_of_the_Picts     4
# ...                                                            ...   ...
# Zirconium                                                Zirconium  4600
# Zoroaster                                                Zoroaster  4601
# Zuid-Gelders                                          Zuid-Gelders  4602
# Zulu                                                          Zulu  4603
# <                                                               -1    -1
#
# [4605 rows x 2 columns]

# %%
## Reading the 'paths_finished.tsv' file as a pandas dataframe
PATH_IN = './data/'
fname = os.path.join(PATH_IN, 'wikispeedia_paths-and-graph/paths_finished.tsv')
df = pd.read_csv(fname, sep = '\t', comment = '#', header = None, names = ['hashedIpAddress','timestamp','durationInSec','path','rating'],encoding = 'UTF-8')
df
# Out:
#         hashedIpAddress   timestamp  durationInSec  \
# 0      6a3701d319fc3754  1297740409            166
# 1      3824310e536af032  1344753412             88
# 2      415612e93584d30e  1349298640            138
# 3      64dd5cd342e3780c  1265613925             37
# 4      015245d773376aab  1366730828            175
# ...                 ...         ...            ...
# 51313  15a13a1d66ef5456  1349231015             66
# 51314  2ef7ac844cefda58  1300254138            165
# 51315  12863abb7887f890  1385095372            228
# 51316  19f8284371753362  1298792567             56
# 51317  24b84602179de377  1318122701             30
#
#                                                     path  rating
# 0      14th_century;15th_century;16th_century;Pacific...     NaN
# 1      14th_century;Europe;Africa;Atlantic_slave_trad...     3.0
# 2      14th_century;Niger;Nigeria;British_Empire;Slav...     NaN
# 3         14th_century;Renaissance;Ancient_Greece;Greece     NaN
# ...

# %%
df['pathnum'] = df.apply(lambda x:str(df_article.loc[x.path.split(';')[:]].num.tolist()), axis = 1)
df
# Out:
#         hashedIpAddress   timestamp  durationInSec  \
# 0      6a3701d319fc3754  1297740409            166
# 1      3824310e536af032  1344753412             88
# 2      415612e93584d30e  1349298640            138
# 3      64dd5cd342e3780c  1265613925             37
# 4      015245d773376aab  1366730828            175
# ...                 ...         ...            ...
# 51313  15a13a1d66ef5456  1349231015             66
# 51314  2ef7ac844cefda58  1300254138            165
# 51315  12863abb7887f890  1385095372            228
# 51316  19f8284371753362  1298792567             56
# 51317  24b84602179de377  1318122701             30
#
#                                                     path  rating  \
# 0      14th_century;15th_century;16th_century;Pacific...     NaN
# 1      14th_century;Europe;Africa;Atlantic_slave_trad...     3.0
# 2      14th_century;Niger;Nigeria;British_Empire;Slav...     NaN
# 3         14th_century;Renaissance;Ancient_Greece;Greece     NaN
# ...
