# %%
import os 
import re
import pickle

import numpy as np
import pandas as pd

from sklearn.metrics import roc_auc_score

# %% [markdown]
# # Utils

# %%
def crawl_paths(experiment_name):
    """
    Crawls the paths and gathers the configuration and results files created from the 
    """
    paths = []
    for (dirpath, dirnames, filenames) in os.walk(experiment_name):
        files = [os.path.join(dirpath, file) for file in filenames]
        paths.extend(files)
    configs = [path for path in paths if 'config.yaml' in path]
    xvals = [path for path in paths if 'xval' in path and 'results' in path]

    full_paths = {}        
    date_re = re.compile('(.*202[0-9]_[0-9]+_[0-9]+_[0-9]+/)')
    model_re = re.compile('.*logger/(.*)/')
    fold_re = re.compile('.*f([\-0-9]+)')
    for config_path in configs:
        try:
            experiment_date_path = date_re.findall(config_path)[0]
            exp_xvals = [xval for xval in xvals if experiment_date_path in xval]
            full_paths[experiment_date_path] = {
                'config': config_path,
                'xval': exp_xvals[0],
            }
        except IndexError:
            continue

    return full_paths

# %%
def look_demographics(path):
    paths_lstm = crawl_paths(path)

    with open('../../data/beerslaw/features/raw/rankings.pkl', 'rb') as fp:
        post_test = pickle.load(fp)
        post_test = post_test.set_index('username')
    demographics = ['gender', 'language', 'field', 'year']
    scores = {dem: {} for dem in demographics}
    
    seed = re.compile('raw_full/([0-9]+\_[0-9]+\_[0-9]+\_[0-9]+)/')
    cluster_iter = re.compile('/([0-9]+\_[0-9]+)/')
    seed_data = {}
    
    for token in paths_lstm:
        with open(paths_lstm[token]['xval'], 'rb') as fp:
            res = pickle.load(fp)
        try:
            with open(paths_lstm[token]['config'], 'rb') as fp:
                config = pickle.load(fp)
        except pickle.UnpicklingError:
            with open(paths_lstm[token]['config'], 'r') as fp:
                config = yaml.load(fp, Loader=yaml.FullLoader)
            
        path_seed = seed.findall(token)[0] + '_' + cluster_iter.findall(token)[0]
            
        idd = config['id_dictionary']

        test_indices = []
        test_indexes = []
        y_truths = []
        y_preds = []
        y_probas = []
        learner_ids = []
        genders = []
        languages = []
        fields = []
        years = []
        for fold in range(10):
            test_indix = list(res[fold]['test_indices'])
            test_index = list(res[fold]['test_index'])
            x_test = [res['x'][idx] for idx in test_index]
            longenough = [i for i in range(len(x_test)) if len(x_test[i]) > 10]
            test_index = [test_index[i] for i in longenough]
            
            y_truth = [res['y'][idx] for idx in test_index]
            y_pred = list(res[fold]['y_pred'])
            y_pred = [y_pred[idx] for idx in longenough]
            y_proba = list(res[fold]['y_proba'])
            y_proba = [y_proba[idx] for idx in longenough]
            lid = [idd['sequences'][idx]['learner_id'] for idx in test_indix]
            lid = [lid[idx] for idx in longenough]
            gender = [post_test.loc[liid]['gender'] for liid in lid]
            language = [post_test.loc[liid]['language'] for liid in lid]
            field = [post_test.loc[liid]['field'] for liid in lid]
            year = [post_test.loc[liid]['year'] for liid in lid]

            test_indices = test_indices + test_indix
            test_indexes = test_indexes + test_index
            y_truths = y_truths + y_truth
            y_preds = y_preds + y_pred
            y_probas = y_probas + y_proba
            learner_ids = learner_ids + lid
            genders = genders + gender
            languages = languages + language
            fields = fields + field
            years = years + year

        data = {
            'y_test': y_truths,
            'y_pred': y_preds,
            'y_proba': y_probas,
            'learner_ids': learner_ids,
            'gender': genders, 
            'language': languages,
            'field': fields,
            'year': years
        }
        
        seed_data[path_seed] = data
    return seed_data

# %%
def true_positive(y_test, y_pred):
    positive = [i for i in range(len(y_test)) if y_test[i] == 1]
    yt = np.array([y_test[i] for i in positive])
    yp = np.array([y_pred[i] for i in positive])
    return sum(yt == yp) / len(positive)

def false_positive(y_test, y_pred):
    fpositive = [i for i in range(len(y_test)) if y_test[i] == 0]
    yt = np.array([y_test[i] for i in fpositive])
    yp = np.array([y_pred[i] for i in fpositive])
    return sum(yt != yp) / len(fpositive)

def pred_positive(y_test, y_pred):
    positive = [yy for yy in y_pred if yy == 1]
    return len(positive) / len(y_test)

def pred_roc(y_test, y_pred):
    return roc_auc_score(y_test, y_pred)
    
def print_equalised_odds_summary_per_demo(seed_data, seed, demographics): 
    demographics_list = np.unique(seed_data[seed][demographics])
    
    demos = []
    tps = []
    fps = []
    pps = []
    rocs = []
    for demo in demographics_list:
        demo_indices = [i for i in range(len(seed_data[seed][demographics])) if seed_data[seed][demographics][i] == demo]
        demo_ytest = [seed_data[seed]['y_test'][i] for i in demo_indices]
        demo_ypred = [seed_data[seed]['y_pred'][i] for i in demo_indices]
        tp = true_positive(demo_ytest, demo_ypred)
        fp = false_positive(demo_ytest, demo_ypred)
        pp = pred_positive(demo_ytest, demo_ypred)
        roc = pred_roc(demo_ytest, demo_ypred)
        tps.append(tp)
        fps.append(fp)
        pps.append(pp)
        rocs.append(roc)
        demos.append(demo)
        
        print('  attribute: {} ({})'.format(demo, len(demo_indices)))
        print('      tp: {}\n      fp: {}\n      pp: {}\n      roc: {}\n'.format(tp, fp, pp, roc))
        
        
    print('  Sorted by True Positive')
    pos_indices = np.argsort(tps)
    demos = [demos[idx] for idx in pos_indices]
    sorted_tps = [tps[idx] for idx in pos_indices]
    print_tps = ['{} ({})'.format(demos[i], sorted_tps[i]) for i in range(len(demos))]
    print('     ', print_tps)
    print()
    
    print('  Sorted by False Positives')
    neg_indices = np.argsort(fps)
    demos = [demos[idx] for idx in neg_indices]
    sorted_tns = [tps[idx] for idx in neg_indices]
    print_tps = ['{} ({})'.format(demos[i], sorted_tps[i]) for i in range(len(demos))]
    print('     ', print_tps)
    print()
    
    print('  Sorted by Predicted Positive')
    pps_indices = np.argsort(pps)
    demos = [demos[idx] for idx in pps_indices]
    sorted_pps = [pps[idx] for idx in pps_indices]
    print_pps = ['{} ({})'.format(demos[i], sorted_pps[i]) for i in range(len(demos))]
    print('     ', print_pps)
    print()
    
def print_equalised_odds_summary(seed_data, seed):
    for demographics in ['gender', 'language', 'field', 'year']:
        print('='*100)
        print('ATTRIBUTE: {}'.format(demographics))
        print_equalised_odds_summary_per_demo(seed_data, seed, demographics)
        print()
        print()
        
def average_across_seeds(seed_data):
    seeds = list(seed_data.keys())
    ypreds = []
    yprobas = []
    ytests = []
    genders = []
    languages = []
    fields = []
    years = []
    lids = []
    for learner_id in seed_data[seeds[0]]['learner_ids']:
        ypred = np.sum([seed_data[seed]['y_pred'][seed_data[seed]['learner_ids'].index(learner_id)] for seed in seeds])
        ypred /= len(seeds)
        ypred = int(ypred)
        ypreds.append(ypred)
        
        yproba = np.sum([seed_data[seed]['y_proba'][seed_data[seed]['learner_ids'].index(learner_id)] for seed in seeds])
        yproba /= len(seeds)
        yprobas.append(yproba)
        
        ytests.append(seed_data[seeds[0]]['y_test'][seed_data[seeds[0]]['learner_ids'].index(learner_id)])
        genders.append(seed_data[seeds[0]]['gender'][seed_data[seeds[0]]['learner_ids'].index(learner_id)])
        languages.append(seed_data[seeds[0]]['language'][seed_data[seeds[0]]['learner_ids'].index(learner_id)])
        fields.append(seed_data[seeds[0]]['field'][seed_data[seeds[0]]['learner_ids'].index(learner_id)])
        years.append(seed_data[seeds[0]]['year'][seed_data[seeds[0]]['learner_ids'].index(learner_id)])
        lids.append(learner_id)
        
    seed_data['all_data'] = {
        'y_test': ytests,
        'y_pred': ypreds,
        'y_proba': yprobas,
        'learner_ids': lids,
        'gender': genders, 
        'language': languages,
        'field': fields,
        'year': years
    }
    return seed_data

# %%
path = '../../data/beerslaw/algos_results/lstm'
seed_data = look_demographics(path)
seed_data = average_across_seeds(seed_data)
eo = print_equalised_odds_summary(seed_data, 'all_data')
# Out:
# ====================================================================================================
# ATTRIBUTE: gender
#   attribute: 1 (135)
#       tp: 0.4909090909090909
#       fp: 0.1125
#       pp: 0.26666666666666666
#       roc: 0.6892045454545455
#
#   attribute: 2 (108)
#       tp: 0.5283018867924528
#       fp: 0.09090909090909091
#       pp: 0.3055555555555556
#       roc: 0.7186963979416808
#
#   attribute: 3 (4)
#       tp: 0.0
#       fp: 0.0
#       pp: 0.0
#       roc: 0.5
#
#   attribute: 4 (7)
#       tp: 0.5
#       fp: 0.0
#       pp: 0.14285714285714285
#       roc: 0.75
#
#   Sorted by True Positive
#       ['3 (0.0)', '1 (0.4909090909090909)', '4 (0.5)', '2 (0.5283018867924528)']
#
#   Sorted by False Positives
#       ['4 (0.0)', '2 (0.4909090909090909)', '1 (0.5)', '3 (0.5283018867924528)']
#
#   Sorted by Predicted Positive
#       ['1 (0.0)', '3 (0.14285714285714285)', '4 (0.26666666666666666)', '2 (0.3055555555555556)']
#
#
#
# ====================================================================================================
# ATTRIBUTE: language
#   attribute: Deutsch (178)
#       tp: 0.5365853658536586
#       fp: 0.10416666666666667
#       pp: 0.30337078651685395
#       roc: 0.716209349593496
#
#   attribute: Français (76)
#       tp: 0.41379310344827586
#       fp: 0.0851063829787234
#       pp: 0.21052631578947367
#       roc: 0.6643433602347762
#
#   Sorted by True Positive
#       ['Français (0.41379310344827586)', 'Deutsch (0.5365853658536586)']
#
#   Sorted by False Positives
#       ['Deutsch (0.41379310344827586)', 'Français (0.5365853658536586)']
#
#   Sorted by Predicted Positive
#       ['Français (0.21052631578947367)', 'Deutsch (0.30337078651685395)']
#
#
#
# ====================================================================================================
# ATTRIBUTE: field
#   attribute: Biology (25)
#       tp: 0.7142857142857143
#       fp: 0.0
#       pp: 0.2
#       roc: 0.8571428571428572
#
#   attribute: Chemistry (160)
#       tp: 0.44
#       fp: 0.09411764705882353
#       pp: 0.25625
#       roc: 0.6729411764705882
#
#   attribute: Chemistry, Textiles (52)
#       tp: 0.6296296296296297
#       fp: 0.24
#       pp: 0.4423076923076923
#       roc: 0.6948148148148149
#
#   attribute: Fast track (5)
#       tp: 0.0
#       fp: 0.0
#       pp: 0.0
#       roc: 0.5
#
#   attribute: Pharma Chemistry (12)
#       tp: 1.0
#       fp: 0.0
#       pp: 0.08333333333333333
#       roc: 1.0
#
#   Sorted by True Positive
#       ['Fast track (0.0)', 'Chemistry (0.44)', 'Chemistry, Textiles (0.6296296296296297)', 'Biology (0.7142857142857143)', 'Pharma Chemistry (1.0)']
#
#   Sorted by False Positives
#       ['Fast track (0.0)', 'Biology (0.44)', 'Pharma Chemistry (0.6296296296296297)', 'Chemistry (0.7142857142857143)', 'Chemistry, Textiles (1.0)']
#
#   Sorted by Predicted Positive
#       ['Chemistry (0.0)', 'Chemistry, Textiles (0.08333333333333333)', 'Fast track (0.2)', 'Biology (0.25625)', 'Pharma Chemistry (0.4423076923076923)']
#
#
#
# ====================================================================================================
# ATTRIBUTE: year
#   attribute: 1st (97)
#       tp: 0.4411764705882353
#       fp: 0.14285714285714285
#       pp: 0.24742268041237114
#       roc: 0.6491596638655462
#
#   attribute: 2nd (108)
#       tp: 0.4791666666666667
#       fp: 0.06666666666666667
#       pp: 0.25
#       roc: 0.70625
#
#   attribute: 3rd (49)
#       tp: 0.6206896551724138
#       fp: 0.05
#       pp: 0.3877551020408163
#       roc: 0.7853448275862068
#
#   Sorted by True Positive
#       ['1st (0.4411764705882353)', '2nd (0.4791666666666667)', '3rd (0.6206896551724138)']
#
#   Sorted by False Positives
#       ['3rd (0.4411764705882353)', '2nd (0.4791666666666667)', '1st (0.6206896551724138)']
#
#   Sorted by Predicted Positive
#       ['3rd (0.24742268041237114)', '2nd (0.25)', '1st (0.3877551020408163)']

# %%
roc_auc_score(seed_data['all_data']['y_test'], seed_data['all_data']['y_proba'])
# Out:
# 0.5229320229320229

# %%
path = '../../data/beerslaw/algos_results/ts_attention/'
seed_data = look_demographics(path)
seed_data = average_across_seeds(seed_data)
eo = print_equalised_odds_summary(seed_data, 'all_data')
# Out:
# ====================================================================================================
# ATTRIBUTE: gender
#   attribute: 1 (135)
#       tp: 0.5272727272727272
#       fp: 0.1625
#       pp: 0.3111111111111111
#       roc: 0.6823863636363637
#
#   attribute: 2 (108)
#       tp: 0.5283018867924528
#       fp: 0.09090909090909091
#       pp: 0.3055555555555556
#       roc: 0.7186963979416808
#
#   attribute: 3 (4)
#       tp: 0.0
#       fp: 0.0
#       pp: 0.0
#       roc: 0.5
#
#   attribute: 4 (7)
#       tp: 0.5
#       fp: 0.0
#       pp: 0.14285714285714285
#       roc: 0.75
#
#   Sorted by True Positive
#       ['3 (0.0)', '4 (0.5)', '1 (0.5272727272727272)', '2 (0.5283018867924528)']
#
#   Sorted by False Positives
#       ['1 (0.0)', '2 (0.5)', '4 (0.5272727272727272)', '3 (0.5283018867924528)']
#
#   Sorted by Predicted Positive
#       ['4 (0.0)', '3 (0.14285714285714285)', '2 (0.3055555555555556)', '1 (0.3111111111111111)']
#
#
#
# ====================================================================================================
# ATTRIBUTE: language
#   attribute: Deutsch (178)
#       tp: 0.5609756097560976
#       fp: 0.11458333333333333
#       pp: 0.3202247191011236
#       roc: 0.7231961382113821
#
#   attribute: Français (76)
#       tp: 0.41379310344827586
#       fp: 0.14893617021276595
#       pp: 0.25
#       roc: 0.6324284666177549
#
#   Sorted by True Positive
#       ['Français (0.41379310344827586)', 'Deutsch (0.5609756097560976)']
#
#   Sorted by False Positives
#       ['Français (0.41379310344827586)', 'Deutsch (0.5609756097560976)']
#
#   Sorted by Predicted Positive
#       ['Deutsch (0.25)', 'Français (0.3202247191011236)']
#
#
#
# ====================================================================================================
# ATTRIBUTE: field
#   attribute: Biology (25)
#       tp: 0.5714285714285714
#       fp: 0.05555555555555555
#       pp: 0.2
#       roc: 0.7579365079365079
#
#   attribute: Chemistry (160)
#       tp: 0.4666666666666667
#       fp: 0.10588235294117647
#       pp: 0.275
#       roc: 0.6803921568627451
#
#   attribute: Chemistry, Textiles (52)
#       tp: 0.6666666666666666
#       fp: 0.32
#       pp: 0.5
#       roc: 0.6733333333333332
#
#   attribute: Fast track (5)
#       tp: 0.0
#       fp: 0.0
#       pp: 0.0
#       roc: 0.5
#
#   attribute: Pharma Chemistry (12)
#       tp: 1.0
#       fp: 0.0
#       pp: 0.08333333333333333
#       roc: 1.0
#
#   Sorted by True Positive
#       ['Fast track (0.0)', 'Chemistry (0.4666666666666667)', 'Biology (0.5714285714285714)', 'Chemistry, Textiles (0.6666666666666666)', 'Pharma Chemistry (1.0)']
#
#   Sorted by False Positives
#       ['Chemistry, Textiles (0.0)', 'Pharma Chemistry (0.4666666666666667)', 'Fast track (0.5714285714285714)', 'Chemistry (0.6666666666666666)', 'Biology (1.0)']
#
#   Sorted by Predicted Positive
#       ['Chemistry (0.0)', 'Biology (0.08333333333333333)', 'Chemistry, Textiles (0.2)', 'Pharma Chemistry (0.275)', 'Fast track (0.5)']
#
#
#
# ====================================================================================================
# ATTRIBUTE: year
#   attribute: 1st (97)
#       tp: 0.5
#       fp: 0.19047619047619047
#       pp: 0.29896907216494845
#       roc: 0.6547619047619049
#
#   attribute: 2nd (108)
#       tp: 0.4583333333333333
#       fp: 0.08333333333333333
#       pp: 0.25
#       roc: 0.6874999999999999
#
#   attribute: 3rd (49)
#       tp: 0.6551724137931034
#       fp: 0.05
#       pp: 0.40816326530612246
#       roc: 0.8025862068965516
#
#   Sorted by True Positive
#       ['2nd (0.4583333333333333)', '1st (0.5)', '3rd (0.6551724137931034)']
#
#   Sorted by False Positives
#       ['3rd (0.4583333333333333)', '1st (0.5)', '2nd (0.6551724137931034)']
#
#   Sorted by Predicted Positive
#       ['1st (0.25)', '3rd (0.29896907216494845)', '2nd (0.40816326530612246)']

# %%
roc_auc_score(seed_data['all_data']['y_test'], seed_data['all_data']['y_proba'])
# Out:
# 0.5035595035595035

# %%
import yaml
yaml_path = '../../data/beerslaw/algos_results/ts_attention/1_15/chemlab-nonnested/simplestate_secondslstm/binconcepts/ts_attention/raw_full/2022_03_03_0/config.yaml'
with open(yaml_path, 'rb') as fp:
    yy = pickle.load(fp)

# %%
yy
# Out:
# {'paths': {'sequenced_simulations': '../data/sequenced_simulations/'},
#  'experiment': {'class_name': 'binconcepts',
#   'root_name': 'chemlab-nonnested/simplestate_secondslstm/binconcepts/ts_attention/raw_full/',
#   'name': '2022_03_03_0',
#   'old_root_name': 'blank/simplestate_secondslstm',
#   'random_seed': 129,
#   'n_folds': 'blank',
#   'n_classes': 2,
#   'class_map': '../data/experiment_keys/permutation_maps/nconcepts_binary.yaml'},
#  'data': {'min_length': 0,
#   'pipeline': {'sequencer': 'simplestate_secondslstm',
#    'sequencer_interval': 5,
#    'sequencer_dragasclick': True,
#    'concatenator': {'type': 'chemconcat', 'tasks': ['2']},
#    'demographic_filter': 'chemlab',
#    'event_filter': 'nofilt',
#    'break_filter': 'cumulseconds',
#    'break_threshold': 0.6,
#    'adjuster': 'full',
#    'encoder': 'raw',
#    'skipgram_weights': '',
#    'skipgram_map': '',
#    'aggregator': 'minmax',
#    'encoders_aggregators_pairs': {1: ['actionspan', 'normagg'],
#     2: ['1hot', 'aveagg']}},
#   'adjuster': {'limit': 900, 'limits': [10]},
#   'filters': {'interactionlimit': 10}},
#  'ML': {'pipeline': {'outerfold_index': -10,
#    'gs_splitter': 'stratkf',
#    'inner_splitter': 'stratkf',
#    'outer_splitter': 'stratkf',
#    'sampler': 'nosplr',
#    'task': 'classification',
#    'model': 'ts_attention',
#    'xvalidator': 'nonnested',
#    'scorer': '2clfscorer',
#    'gridsearch': 'nogs',
#    'test_pad': False,
#    'val_pad': False,
#    'train_pad': True,
#    'models': ['rf']},
#   'permutation': {'label_map': 'vector_labels'},
#   'models': {'classifiers': {'lstm': {'seed': 1,
#      'batch_size': 16,
#      'cell_type': 'GRU',
#      'dropout': 0.02,
#      'early_stopping': False,
#      'epochs': 30,
#      'loss': 'auc',
#      'n_cells': [32],
#      'n_layers': 1,
#      'optimiser': 'adam',
#      'padding_value': -1,
#      'shuffle': True,
#      'verbose': 1,
#      'save_best_model': False,
#      'flatten': 'average'},
#     'ssan': {'save_best_model': False,
#      'batch_size': 16,
#      'dropout': 0.02,
#      'early_stopping': False,
#      'epochs': 30,
#      'key_cells': 8,
#      'value_cells': 8,
#      'query_cells': 8,
#      'loss': 'auc',
#      'optimiser': 'adam',
#      'padding': 'valid',
#      'padding_value': -1,
#      'pool_size': 64,
#      'seed': 1,
#      'shuffle': True,
#      'stride': 32,
#      'gru_cells': 32,
#      'verbose': 1}}},
#   'splitters': {'n_folds': 10,
#    'stratkf': {'shuffle': True, 'stratifier_col': 'y'},
#    'flatstrat': {'test_path': '../data/experiment_keys/flatstrat_testusernames.pkl',
#     'train_path': '../data/experiment_keys/flatstrat_trainusernames.pkl'}},
#   'xvalidators': {'nested_xval': {'inner_n_folds': 10,
#     'outer_n_folds': 10,
#     'optim_scoring': 'roc'}},
#   'scorers': {'scoring_metrics': ['accuracy',
#     'balanced_accuracy',
#     'precision',
#     'recall',
#     'roc',
#     'balanced_auc',
#     'overall_auc'],
#    'carry_on': True}},
#  'test': False,
#  'classification': False,
#  'early_clf': False,
#  'nonnested_seedsearch': True,
#  'classification_comparison': False,
#  'skipgram_comparison': False,
#  'early_prediction': False,
#  'checkpoint': False,
#  'sequencer': 'simplestate_secondslstm',
#  'adaptiveseconds': '1',
#  'classname': '',
#  'skipgram': '',
#  'models': '',
#  'model': 'ts_attention',
#  'outerfold_index': '',
#  'fulltime': False,
#  'scrop': False,
#  'model_seeds': '1.15',
#  'id_dictionary': {'sequences': {0: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2013_lidsvdphyjs_t2_sequenced.pkl',
#     'length': 69,
#     'learner_id': 'svdphyjs'},
#    1: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lid2ae6q3hw_t2_sequenced.pkl',
#     'length': 139,
#     'learner_id': '2ae6q3hw'},
#    2: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2013_lid8jp62suc_t2_sequenced.pkl',
#     'length': 24,
#     'learner_id': '8jp62suc'},
#    3: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lide93na59g_t2_sequenced.pkl',
#     'length': 60,
#     'learner_id': 'e93na59g'},
#    4: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidchm4sr6j_t2_sequenced.pkl',
#     'length': 23,
#     'learner_id': 'chm4sr6j'},
#    5: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lidgc663sap_t2_sequenced.pkl',
#     'length': 47,
#     'learner_id': 'gc663sap'},
#    6: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_lid8nh4zvcp_t2_sequenced.pkl',
#     'length': 74,
#     'learner_id': '8nh4zvcp'},
#    7: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3102_lid7t9zwtmr_t2_sequenced.pkl',
#     'length': 55,
#     'learner_id': '7t9zwtmr'},
#    8: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lidwvxkvhne_t2_sequenced.pkl',
#     'length': 15,
#     'learner_id': 'wvxkvhne'},
#    9: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lid43e33t3h_t2_sequenced.pkl',
#     'length': 56,
#     'learner_id': '43e33t3h'},
#    10: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lida3vdjxy9_t2_sequenced.pkl',
#     'length': 74,
#     'learner_id': 'a3vdjxy9'},
#    11: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_1320_lidmkw5afyy_t2_sequenced.pkl',
#     'length': 16,
#     'learner_id': 'mkw5afyy'},
#    12: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0312_liddq4zzkyt_t2_sequenced.pkl',
#     'length': 105,
#     'learner_id': 'dq4zzkyt'},
#    13: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3021_lid5f4q4ng5_t2_sequenced.pkl',
#     'length': 106,
#     'learner_id': '5f4q4ng5'},
#    14: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lidtemu2736_t2_sequenced.pkl',
#     'length': 39,
#     'learner_id': 'temu2736'},
#    15: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lidf54jkrsw_t2_sequenced.pkl',
#     'length': 127,
#     'learner_id': 'f54jkrsw'},
#    16: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lidujpk3gf4_t2_sequenced.pkl',
#     'length': 32,
#     'learner_id': 'ujpk3gf4'},
#    17: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2310_lidjkbx6axr_t2_sequenced.pkl',
#     'length': 48,
#     'learner_id': 'jkbx6axr'},
#    18: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3102_lidvwfpuqaz_t2_sequenced.pkl',
#     'length': 14,
#     'learner_id': 'vwfpuqaz'},
#    19: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_lidw7asnymz_t2_sequenced.pkl',
#     'length': 70,
#     'learner_id': 'w7asnymz'},
#    20: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lid2hr6mkdc_t2_sequenced.pkl',
#     'length': 153,
#     'learner_id': '2hr6mkdc'},
#    21: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidnrxpa2ac_t2_sequenced.pkl',
#     'length': 21,
#     'learner_id': 'nrxpa2ac'},
#    22: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lid5zrt4f8z_t2_sequenced.pkl',
#     'length': 42,
#     'learner_id': '5zrt4f8z'},
#    23: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3210_lidm3d89p29_t2_sequenced.pkl',
#     'length': 69,
#     'learner_id': 'm3d89p29'},
#    24: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0312_lidvjr7tshm_t2_sequenced.pkl',
#     'length': 24,
#     'learner_id': 'vjr7tshm'},
#    25: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lidegg8756y_t2_sequenced.pkl',
#     'length': 32,
#     'learner_id': 'egg8756y'},
#    26: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_liduhbpoog9_t2_sequenced.pkl',
#     'length': 14,
#     'learner_id': 'uhbpoog9'},
#    27: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2013_lidbg7x3db2_t2_sequenced.pkl',
#     'length': 135,
#     'learner_id': 'bg7x3db2'},
#    28: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0321_lidxz56yha8_t2_sequenced.pkl',
#     'length': 107,
#     'learner_id': 'xz56yha8'},
#    29: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_lidrrykpeqz_t2_sequenced.pkl',
#     'length': 65,
#     'learner_id': 'rrykpeqz'},
#    30: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3210_lid55yavcue_t2_sequenced.pkl',
#     'length': 36,
#     'learner_id': '55yavcue'},
#    31: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidp44vw7td_t2_sequenced.pkl',
#     'length': 122,
#     'learner_id': 'p44vw7td'},
#    32: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lidfu6nsdhs_t2_sequenced.pkl',
#     'length': 147,
#     'learner_id': 'fu6nsdhs'},
#    33: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2301_lid2ejxq2u8_t2_sequenced.pkl',
#     'length': 21,
#     'learner_id': '2ejxq2u8'},
#    34: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_lidky8kttpv_t2_sequenced.pkl',
#     'length': 132,
#     'learner_id': 'ky8kttpv'},
#    35: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_1320_lidrdbqasqa_t2_sequenced.pkl',
#     'length': 145,
#     'learner_id': 'rdbqasqa'},
#    36: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_lidzgyc948n_t2_sequenced.pkl',
#     'length': 53,
#     'learner_id': 'zgyc948n'},
#    37: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lidc9dj36r7_t2_sequenced.pkl',
#     'length': 160,
#     'learner_id': 'c9dj36r7'},
#    38: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2310_lidxvsgn53d_t2_sequenced.pkl',
#     'length': 126,
#     'learner_id': 'xvsgn53d'},
#    39: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0312_lidqsd9cb5e_t2_sequenced.pkl',
#     'length': 151,
#     'learner_id': 'qsd9cb5e'},
#    40: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3102_lid9pjrsbth_t2_sequenced.pkl',
#     'length': 111,
#     'learner_id': '9pjrsbth'},
#    41: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3210_lidcp7mfn24_t2_sequenced.pkl',
#     'length': 27,
#     'learner_id': 'cp7mfn24'},
#    42: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lidj9qgkaej_t2_sequenced.pkl',
#     'length': 104,
#     'learner_id': 'j9qgkaej'},
#    43: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lid982cf4dn_t2_sequenced.pkl',
#     'length': 24,
#     'learner_id': '982cf4dn'},
#    44: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lid4zsmj6s3_t2_sequenced.pkl',
#     'length': 95,
#     'learner_id': '4zsmj6s3'},
#    45: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0312_lid85pdk9mq_t2_sequenced.pkl',
#     'length': 18,
#     'learner_id': '85pdk9mq'},
#    46: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3210_lidhf8uz5t3_t2_sequenced.pkl',
#     'length': 56,
#     'learner_id': 'hf8uz5t3'},
#    47: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2310_lidk7p5eryf_t2_sequenced.pkl',
#     'length': 14,
#     'learner_id': 'k7p5eryf'},
#    48: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3201_lidx844md8u_t2_sequenced.pkl',
#     'length': 30,
#     'learner_id': 'x844md8u'},
#    49: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lidbaqyfz2h_t2_sequenced.pkl',
#     'length': 283,
#     'learner_id': 'baqyfz2h'},
#    50: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lid2ep3hayy_t2_sequenced.pkl',
#     'length': 9,
#     'learner_id': '2ep3hayy'},
#    51: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_lidjwntt96k_t2_sequenced.pkl',
#     'length': 217,
#     'learner_id': 'jwntt96k'},
#    52: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2103_lidwktpsvp8_t2_sequenced.pkl',
#     'length': 181,
#     'learner_id': 'wktpsvp8'},
#    53: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lidh75kp27p_t2_sequenced.pkl',
#     'length': 39,
#     'learner_id': 'h75kp27p'},
#    54: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2130_lid26z3wbqz_t2_sequenced.pkl',
#     'length': 18,
#     'learner_id': '26z3wbqz'},
#    55: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2103_lidx5sm9pfu_t2_sequenced.pkl',
#     'length': 13,
#     'learner_id': 'x5sm9pfu'},
#    56: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lidmnhmyuhb_t2_sequenced.pkl',
#     'length': 37,
#     'learner_id': 'mnhmyuhb'},
#    57: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_lidtsrnkj8w_t2_sequenced.pkl',
#     'length': 106,
#     'learner_id': 'tsrnkj8w'},
#    58: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3021_liduenn9vgu_t2_sequenced.pkl',
#     'length': 14,
#     'learner_id': 'uenn9vgu'},
#    59: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0123_lid6h5vmwys_t2_sequenced.pkl',
#     'length': 26,
#     'learner_id': '6h5vmwys'},
#    60: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2103_lidybxahrra_t2_sequenced.pkl',
#     'length': 107,
#     'learner_id': 'ybxahrra'},
#    61: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3102_lidu25vrfyy_t2_sequenced.pkl',
#     'length': 34,
#     'learner_id': 'u25vrfyy'},
#    62: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lidrgeb7wr9_t2_sequenced.pkl',
#     'length': 75,
#     'learner_id': 'rgeb7wr9'},
#    63: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3021_lidfavvtnnf_t2_sequenced.pkl',
#     'length': 36,
#     'learner_id': 'favvtnnf'},
#    64: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2130_lidntqpqkpq_t2_sequenced.pkl',
#     'length': 22,
#     'learner_id': 'ntqpqkpq'},
#    65: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2013_lidnj859xxh_t2_sequenced.pkl',
#     'length': 31,
#     'learner_id': 'nj859xxh'},
#    66: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidfh76v5qx_t2_sequenced.pkl',
#     'length': 130,
#     'learner_id': 'fh76v5qx'},
#    67: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lidt6rjyw6s_t2_sequenced.pkl',
#     'length': 27,
#     'learner_id': 't6rjyw6s'},
#    68: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0321_lidvhsgf3xa_t2_sequenced.pkl',
#     'length': 22,
#     'learner_id': 'vhsgf3xa'},
#    69: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lidg6z8qykr_t2_sequenced.pkl',
#     'length': 96,
#     'learner_id': 'g6z8qykr'},
#    70: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3210_lidrve4n5nv_t2_sequenced.pkl',
#     'length': 185,
#     'learner_id': 'rve4n5nv'},
#    71: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lid5h9umyr6_t2_sequenced.pkl',
#     'length': 15,
#     'learner_id': '5h9umyr6'},
#    72: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidv5w2e3zw_t2_sequenced.pkl',
#     'length': 56,
#     'learner_id': 'v5w2e3zw'},
#    73: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lidnw65tu6j_t2_sequenced.pkl',
#     'length': 98,
#     'learner_id': 'nw65tu6j'},
#    74: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_lidmhek2323_t2_sequenced.pkl',
#     'length': 67,
#     'learner_id': 'mhek2323'},
#    75: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0312_lidrdy7sx9b_t2_sequenced.pkl',
#     'length': 29,
#     'learner_id': 'rdy7sx9b'},
#    76: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lidtvtbbfhg_t2_sequenced.pkl',
#     'length': 23,
#     'learner_id': 'tvtbbfhg'},
#    77: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lidcaq55qe8_t2_sequenced.pkl',
#     'length': 82,
#     'learner_id': 'caq55qe8'},
#    78: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2130_liddrccqhk4_t2_sequenced.pkl',
#     'length': 22,
#     'learner_id': 'drccqhk4'},
#    79: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3201_lidtcnba4ca_t2_sequenced.pkl',
#     'length': 59,
#     'learner_id': 'tcnba4ca'},
#    80: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lidfs32fqe3_t2_sequenced.pkl',
#     'length': 20,
#     'learner_id': 'fs32fqe3'},
#    81: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0312_lidr74r26kt_t2_sequenced.pkl',
#     'length': 79,
#     'learner_id': 'r74r26kt'},
#    82: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2013_lide3b96acv_t2_sequenced.pkl',
#     'length': 47,
#     'learner_id': 'e3b96acv'},
#    83: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_1032_lidur9sxzx7_t2_sequenced.pkl',
#     'length': 29,
#     'learner_id': 'ur9sxzx7'},
#    84: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_1032_liduqven68r_t2_sequenced.pkl',
#     'length': 53,
#     'learner_id': 'uqven68r'},
#    85: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2013_lidm35ub35g_t2_sequenced.pkl',
#     'length': 50,
#     'learner_id': 'm35ub35g'},
#    86: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lidjx3yyy26_t2_sequenced.pkl',
#     'length': 54,
#     'learner_id': 'jx3yyy26'},
#    87: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_lid5es5yqs8_t2_sequenced.pkl',
#     'length': 51,
#     'learner_id': '5es5yqs8'},
#    88: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidydws5xx9_t2_sequenced.pkl',
#     'length': 54,
#     'learner_id': 'ydws5xx9'},
#    89: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lidwxz98urt_t2_sequenced.pkl',
#     'length': 139,
#     'learner_id': 'wxz98urt'},
#    90: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidqdp9ant4_t2_sequenced.pkl',
#     'length': 113,
#     'learner_id': 'qdp9ant4'},
#    91: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3102_lid63xqh9t5_t2_sequenced.pkl',
#     'length': 30,
#     'learner_id': '63xqh9t5'},
#    92: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lidbeypwbck_t2_sequenced.pkl',
#     'length': 21,
#     'learner_id': 'beypwbck'},
#    93: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_lidp6mkaa4e_t2_sequenced.pkl',
#     'length': 38,
#     'learner_id': 'p6mkaa4e'},
#    94: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3021_lidmwwddfvg_t2_sequenced.pkl',
#     'length': 82,
#     'learner_id': 'mwwddfvg'},
#    95: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_liduqw5vh3j_t2_sequenced.pkl',
#     'length': 86,
#     'learner_id': 'uqw5vh3j'},
#    96: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_liduhq3p7yr_t2_sequenced.pkl',
#     'length': 22,
#     'learner_id': 'uhq3p7yr'},
#    97: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0321_lidp6269reg_t2_sequenced.pkl',
#     'length': 16,
#     'learner_id': 'p6269reg'},
#    98: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2103_lidwnurkn96_t2_sequenced.pkl',
#     'length': 54,
#     'learner_id': 'wnurkn96'},
#    99: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lidupp6pqmx_t2_sequenced.pkl',
#     'length': 522,
#     'learner_id': 'upp6pqmx'},
#    100: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidbebyve9b_t2_sequenced.pkl',
#     'length': 156,
#     'learner_id': 'bebyve9b'},
#    101: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lid3vsn2h9f_t2_sequenced.pkl',
#     'length': 68,
#     'learner_id': '3vsn2h9f'},
#    102: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0123_lidv5gwycag_t2_sequenced.pkl',
#     'length': 142,
#     'learner_id': 'v5gwycag'},
#    103: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_liduswb2jez_t2_sequenced.pkl',
#     'length': 42,
#     'learner_id': 'uswb2jez'},
#    104: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lidnsj6k2rg_t2_sequenced.pkl',
#     'length': 102,
#     'learner_id': 'nsj6k2rg'},
#    105: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidw25mph3c_t2_sequenced.pkl',
#     'length': 56,
#     'learner_id': 'w25mph3c'},
#    106: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_1203_lidupkt7qb4_t2_sequenced.pkl',
#     'length': 108,
#     'learner_id': 'upkt7qb4'},
#    107: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lidwbdyh5vk_t2_sequenced.pkl',
#     'length': 216,
#     'learner_id': 'wbdyh5vk'},
#    108: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0123_lidmp2aa258_t2_sequenced.pkl',
#     'length': 47,
#     'learner_id': 'mp2aa258'},
#    109: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lidwpszzhxa_t2_sequenced.pkl',
#     'length': 29,
#     'learner_id': 'wpszzhxa'},
#    110: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_liduqzxsym7_t2_sequenced.pkl',
#     'length': 33,
#     'learner_id': 'uqzxsym7'},
#    111: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_lidxw9qt6r4_t2_sequenced.pkl',
#     'length': 21,
#     'learner_id': 'xw9qt6r4'},
#    112: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lide22ppyf7_t2_sequenced.pkl',
#     'length': 109,
#     'learner_id': 'e22ppyf7'},
#    113: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_lidxsxkdf7k_t2_sequenced.pkl',
#     'length': 109,
#     'learner_id': 'xsxkdf7k'},
#    114: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_1320_lidyc3vmnuf_t2_sequenced.pkl',
#     'length': 34,
#     'learner_id': 'yc3vmnuf'},
#    115: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2301_lid84nmc3df_t2_sequenced.pkl',
#     'length': 221,
#     'learner_id': '84nmc3df'},
#    116: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3021_lidunkrat9w_t2_sequenced.pkl',
#     'length': 34,
#     'learner_id': 'unkrat9w'},
#    117: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lidecy9k833_t2_sequenced.pkl',
#     'length': 41,
#     'learner_id': 'ecy9k833'},
#    118: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3210_lidurwu33jd_t2_sequenced.pkl',
#     'length': 25,
#     'learner_id': 'urwu33jd'},
#    119: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lid4k4kc2k6_t2_sequenced.pkl',
#     'length': 24,
#     'learner_id': '4k4kc2k6'},
#    120: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0123_lidr2q9q35x_t2_sequenced.pkl',
#     'length': 42,
#     'learner_id': 'r2q9q35x'},
#    121: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2130_lidfryxwskq_t2_sequenced.pkl',
#     'length': 11,
#     'learner_id': 'fryxwskq'},
#    122: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lid892r4czm_t2_sequenced.pkl',
#     'length': 54,
#     'learner_id': '892r4czm'},
#    123: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_lidaurjfgnn_t2_sequenced.pkl',
#     'length': 31,
#     'learner_id': 'aurjfgnn'},
#    124: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2013_lidcdq4drkk_t2_sequenced.pkl',
#     'length': 75,
#     'learner_id': 'cdq4drkk'},
#    125: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidp5t7d3sb_t2_sequenced.pkl',
#     'length': 148,
#     'learner_id': 'p5t7d3sb'},
#    126: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lid4rhnvke9_t2_sequenced.pkl',
#     'length': 35,
#     'learner_id': '4rhnvke9'},
#    127: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lidxpyjyx4m_t2_sequenced.pkl',
#     'length': 28,
#     'learner_id': 'xpyjyx4m'},
#    128: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidmzjq6z9t_t2_sequenced.pkl',
#     'length': 33,
#     'learner_id': 'mzjq6z9t'},
#    129: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0312_lido9ffsiwt_t2_sequenced.pkl',
#     'length': 40,
#     'learner_id': 'o9ffsiwt'},
#    130: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3102_lidjydsy777_t2_sequenced.pkl',
#     'length': 173,
#     'learner_id': 'jydsy777'},
#    131: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lidxj86wyup_t2_sequenced.pkl',
#     'length': 32,
#     'learner_id': 'xj86wyup'},
#    132: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2310_lidedmrufua_t2_sequenced.pkl',
#     'length': 112,
#     'learner_id': 'edmrufua'},
#    133: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3021_lid7xhcecye_t2_sequenced.pkl',
#     'length': 34,
#     'learner_id': '7xhcecye'},
#    134: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lid5m3ka2m2_t2_sequenced.pkl',
#     'length': 112,
#     'learner_id': '5m3ka2m2'},
#    135: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2013_lidsx3vqc32_t2_sequenced.pkl',
#     'length': 35,
#     'learner_id': 'sx3vqc32'},
#    136: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_1302_lid4jchqv4d_t2_sequenced.pkl',
#     'length': 62,
#     'learner_id': '4jchqv4d'},
#    137: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidtsvcrpeg_t2_sequenced.pkl',
#     'length': 66,
#     'learner_id': 'tsvcrpeg'},
#    138: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lid9p9gwu88_t2_sequenced.pkl',
#     'length': 20,
#     'learner_id': '9p9gwu88'},
#    139: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3021_lid6j6u2yct_t2_sequenced.pkl',
#     'length': 14,
#     'learner_id': '6j6u2yct'},
#    140: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lidzs35fg8g_t2_sequenced.pkl',
#     'length': 17,
#     'learner_id': 'zs35fg8g'},
#    141: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_1023_lidh9t9mxtx_t2_sequenced.pkl',
#     'length': 33,
#     'learner_id': 'h9t9mxtx'},
#    142: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0321_lidbqmcqxyx_t2_sequenced.pkl',
#     'length': 25,
#     'learner_id': 'bqmcqxyx'},
#    143: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_1320_lidht865nws_t2_sequenced.pkl',
#     'length': 128,
#     'learner_id': 'ht865nws'},
#    144: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2103_lidqk6q49f4_t2_sequenced.pkl',
#     'length': 115,
#     'learner_id': 'qk6q49f4'},
#    145: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3021_lid39htvmt5_t2_sequenced.pkl',
#     'length': 39,
#     'learner_id': '39htvmt5'},
#    146: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lidmwfdr4ys_t2_sequenced.pkl',
#     'length': 87,
#     'learner_id': 'mwfdr4ys'},
#    147: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lidxdxyjh8j_t2_sequenced.pkl',
#     'length': 190,
#     'learner_id': 'xdxyjh8j'},
#    148: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2013_lidjhrkm85q_t2_sequenced.pkl',
#     'length': 27,
#     'learner_id': 'jhrkm85q'},
#    149: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lid6tg95rzr_t2_sequenced.pkl',
#     'length': 25,
#     'learner_id': '6tg95rzr'},
#    150: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0312_lidsgsxmkfm_t2_sequenced.pkl',
#     'length': 47,
#     'learner_id': 'sgsxmkfm'},
#    151: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidfj5tdybn_t2_sequenced.pkl',
#     'length': 39,
#     'learner_id': 'fj5tdybn'},
#    152: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0123_lidbezdgyya_t2_sequenced.pkl',
#     'length': 60,
#     'learner_id': 'bezdgyya'},
#    153: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lidjwajupwj_t2_sequenced.pkl',
#     'length': 121,
#     'learner_id': 'jwajupwj'},
#    154: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2013_lid6z7nfy2j_t2_sequenced.pkl',
#     'length': 75,
#     'learner_id': '6z7nfy2j'},
#    155: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3102_lideb9iv6v2_t2_sequenced.pkl',
#     'length': 42,
#     'learner_id': 'eb9iv6v2'},
#    156: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_lid4bu2rkv3_t2_sequenced.pkl',
#     'length': 39,
#     'learner_id': '4bu2rkv3'},
#    157: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lidy9tk3ysm_t2_sequenced.pkl',
#     'length': 8,
#     'learner_id': 'y9tk3ysm'},
#    158: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3102_lidj6nndaxp_t2_sequenced.pkl',
#     'length': 21,
#     'learner_id': 'j6nndaxp'},
#    159: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2310_lidnba9d6t2_t2_sequenced.pkl',
#     'length': 50,
#     'learner_id': 'nba9d6t2'},
#    160: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_1203_lids8w65sm5_t2_sequenced.pkl',
#     'length': 25,
#     'learner_id': 's8w65sm5'},
#    161: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidhkvk9vt9_t2_sequenced.pkl',
#     'length': 213,
#     'learner_id': 'hkvk9vt9'},
#    162: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_1203_liddubyutqd_t2_sequenced.pkl',
#     'length': 57,
#     'learner_id': 'dubyutqd'},
#    163: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidsgdgynxy_t2_sequenced.pkl',
#     'length': 72,
#     'learner_id': 'sgdgynxy'},
#    164: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lid3st3y5gc_t2_sequenced.pkl',
#     'length': 263,
#     'learner_id': '3st3y5gc'},
#    165: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2130_lidaraav4jr_t2_sequenced.pkl',
#     'length': 52,
#     'learner_id': 'araav4jr'},
#    166: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2103_lidsz8qvgyv_t2_sequenced.pkl',
#     'length': 16,
#     'learner_id': 'sz8qvgyv'},
#    167: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0321_lidsuyrrcqe_t2_sequenced.pkl',
#     'length': 17,
#     'learner_id': 'suyrrcqe'},
#    168: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lid2xjmtbvz_t2_sequenced.pkl',
#     'length': 51,
#     'learner_id': '2xjmtbvz'},
#    169: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidytrbygud_t2_sequenced.pkl',
#     'length': 88,
#     'learner_id': 'ytrbygud'},
#    170: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lid6fkbh35u_t2_sequenced.pkl',
#     'length': 76,
#     'learner_id': '6fkbh35u'},
#    171: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3021_lidv2cxb3a5_t2_sequenced.pkl',
#     'length': 28,
#     'learner_id': 'v2cxb3a5'},
#    172: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_liday2erc3c_t2_sequenced.pkl',
#     'length': 40,
#     'learner_id': 'ay2erc3c'},
#    173: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lid9bp6yz7m_t2_sequenced.pkl',
#     'length': 420,
#     'learner_id': '9bp6yz7m'},
#    174: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_1230_lidfm5rcvdy_t2_sequenced.pkl',
#     'length': 121,
#     'learner_id': 'fm5rcvdy'},
#    175: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2130_lidr29wzm6f_t2_sequenced.pkl',
#     'length': 135,
#     'learner_id': 'r29wzm6f'},
#    176: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lidy7p64n6z_t2_sequenced.pkl',
#     'length': 33,
#     'learner_id': 'y7p64n6z'},
#    177: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2301_lid9aagpn4d_t2_sequenced.pkl',
#     'length': 58,
#     'learner_id': '9aagpn4d'},
#    178: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidsjz2rptd_t2_sequenced.pkl',
#     'length': 60,
#     'learner_id': 'sjz2rptd'},
#    179: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3210_lidmcjaj2aj_t2_sequenced.pkl',
#     'length': 38,
#     'learner_id': 'mcjaj2aj'},
#    180: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lidujp9fgpn_t2_sequenced.pkl',
#     'length': 31,
#     'learner_id': 'ujp9fgpn'},
#    181: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2130_lidb72hbgvw_t2_sequenced.pkl',
#     'length': 24,
#     'learner_id': 'b72hbgvw'},
#    182: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidevqzjs5p_t2_sequenced.pkl',
#     'length': 58,
#     'learner_id': 'evqzjs5p'},
#    183: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidsmqjhu44_t2_sequenced.pkl',
#     'length': 43,
#     'learner_id': 'smqjhu44'},
#    184: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3102_lidfyf6ag5v_t2_sequenced.pkl',
#     'length': 28,
#     'learner_id': 'fyf6ag5v'},
#    185: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_1032_lidgvqh7qr2_t2_sequenced.pkl',
#     'length': 136,
#     'learner_id': 'gvqh7qr2'},
#    186: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2013_lidwger3sfa_t2_sequenced.pkl',
#     'length': 97,
#     'learner_id': 'wger3sfa'},
#    187: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lid4k4dk9pu_t2_sequenced.pkl',
#     'length': 37,
#     'learner_id': '4k4dk9pu'},
#    188: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_liddbt5na3s_t2_sequenced.pkl',
#     'length': 317,
#     'learner_id': 'dbt5na3s'},
#    189: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3210_lid2crhmbq7_t2_sequenced.pkl',
#     'length': 16,
#     'learner_id': '2crhmbq7'},
#    190: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2103_lidh543nsc8_t2_sequenced.pkl',
#     'length': 33,
#     'learner_id': 'h543nsc8'},
#    191: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0312_lidqkeyp2rg_t2_sequenced.pkl',
#     'length': 16,
#     'learner_id': 'qkeyp2rg'},
#    192: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lidqsx2cc4b_t2_sequenced.pkl',
#     'length': 115,
#     'learner_id': 'qsx2cc4b'},
#    193: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3210_lid6uakv8nx_t2_sequenced.pkl',
#     'length': 40,
#     'learner_id': '6uakv8nx'},
#    194: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2013_lidb2q8ay65_t2_sequenced.pkl',
#     'length': 55,
#     'learner_id': 'b2q8ay65'},
#    195: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2130_lidu6c3cp6c_t2_sequenced.pkl',
#     'length': 43,
#     'learner_id': 'u6c3cp6c'},
#    196: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3021_lid4vuc8rr3_t2_sequenced.pkl',
#     'length': 40,
#     'learner_id': '4vuc8rr3'},
#    197: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lid6bq62prp_t2_sequenced.pkl',
#     'length': 27,
#     'learner_id': '6bq62prp'},
#    198: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_1023_lidr78kg7d3_t2_sequenced.pkl',
#     'length': 211,
#     'learner_id': 'r78kg7d3'},
#    199: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2013_lid47ce49e4_t2_sequenced.pkl',
#     'length': 138,
#     'learner_id': '47ce49e4'},
#    200: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_1230_lidqjfn2j8z_t2_sequenced.pkl',
#     'length': 37,
#     'learner_id': 'qjfn2j8z'},
#    201: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lidt3dwkezr_t2_sequenced.pkl',
#     'length': 155,
#     'learner_id': 't3dwkezr'},
#    202: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidq4z45p85_t2_sequenced.pkl',
#     'length': 97,
#     'learner_id': 'q4z45p85'},
#    203: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3201_lidszvqb37f_t2_sequenced.pkl',
#     'length': 54,
#     'learner_id': 'szvqb37f'},
#    204: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lid9wdm7zue_t2_sequenced.pkl',
#     'length': 59,
#     'learner_id': '9wdm7zue'},
#    205: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2130_lidhrhu4yph_t2_sequenced.pkl',
#     'length': 20,
#     'learner_id': 'hrhu4yph'},
#    206: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_1023_lidg4xpwwac_t2_sequenced.pkl',
#     'length': 15,
#     'learner_id': 'g4xpwwac'},
#    207: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2310_lid5y535ct3_t2_sequenced.pkl',
#     'length': 58,
#     'learner_id': '5y535ct3'},
#    208: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_liddjnysnd6_t2_sequenced.pkl',
#     'length': 145,
#     'learner_id': 'djnysnd6'},
#    209: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3102_lids78drqcg_t2_sequenced.pkl',
#     'length': 34,
#     'learner_id': 's78drqcg'},
#    210: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lidfzagvhvf_t2_sequenced.pkl',
#     'length': 61,
#     'learner_id': 'fzagvhvf'},
#    211: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lids7mdq5tk_t2_sequenced.pkl',
#     'length': 156,
#     'learner_id': 's7mdq5tk'},
#    212: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3021_lidsm8sfpcg_t2_sequenced.pkl',
#     'length': 24,
#     'learner_id': 'sm8sfpcg'},
#    213: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lid5j7hdews_t2_sequenced.pkl',
#     'length': 23,
#     'learner_id': '5j7hdews'},
#    214: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2013_lidzkrr45y5_t2_sequenced.pkl',
#     'length': 57,
#     'learner_id': 'zkrr45y5'},
#    215: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lid88kjzd8b_t2_sequenced.pkl',
#     'length': 43,
#     'learner_id': '88kjzd8b'},
#    216: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lid4e438nww_t2_sequenced.pkl',
#     'length': 300,
#     'learner_id': '4e438nww'},
#    217: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3021_lid26mtbtye_t2_sequenced.pkl',
#     'length': 15,
#     'learner_id': '26mtbtye'},
#    218: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lidoikzz9af_t2_sequenced.pkl',
#     'length': 11,
#     'learner_id': 'oikzz9af'},
#    219: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lidm749z8u9_t2_sequenced.pkl',
#     'length': 608,
#     'learner_id': 'm749z8u9'},
#    220: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_lidm4zvafhs_t2_sequenced.pkl',
#     'length': 120,
#     'learner_id': 'm4zvafhs'},
#    221: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lidd7777ske_t2_sequenced.pkl',
#     'length': 14,
#     'learner_id': 'd7777ske'},
#    222: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_liddmdc53tx_t2_sequenced.pkl',
#     'length': 18,
#     'learner_id': 'dmdc53tx'},
#    223: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lidgpq26qq9_t2_sequenced.pkl',
#     'length': 208,
#     'learner_id': 'gpq26qq9'},
#    224: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3102_lid5a69aw4h_t2_sequenced.pkl',
#     'length': 30,
#     'learner_id': '5a69aw4h'},
#    225: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0123_lid4vtjgtja_t2_sequenced.pkl',
#     'length': 32,
#     'learner_id': '4vtjgtja'},
#    226: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2130_lidryfqnvfh_t2_sequenced.pkl',
#     'length': 41,
#     'learner_id': 'ryfqnvfh'},
#    227: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_lid9sgu2tbg_t2_sequenced.pkl',
#     'length': 18,
#     'learner_id': '9sgu2tbg'},
#    228: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_liddk43m2pe_t2_sequenced.pkl',
#     'length': 120,
#     'learner_id': 'dk43m2pe'},
#    229: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lid9xc2v9vu_t2_sequenced.pkl',
#     'length': 128,
#     'learner_id': '9xc2v9vu'},
#    230: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidjvxejtp9_t2_sequenced.pkl',
#     'length': 125,
#     'learner_id': 'jvxejtp9'},
#    231: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3201_lidzgs84jfy_t2_sequenced.pkl',
#     'length': 49,
#     'learner_id': 'zgs84jfy'},
#    232: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_1302_lid8ethqmkd_t2_sequenced.pkl',
#     'length': 14,
#     'learner_id': '8ethqmkd'},
#    233: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lid76wvaew4_t2_sequenced.pkl',
#     'length': 20,
#     'learner_id': '76wvaew4'},
#    234: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2310_liduthx49rq_t2_sequenced.pkl',
#     'length': 227,
#     'learner_id': 'uthx49rq'},
#    235: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lideau7bsmq_t2_sequenced.pkl',
#     'length': 53,
#     'learner_id': 'eau7bsmq'},
#    236: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2130_lidcb6wcvyn_t2_sequenced.pkl',
#     'length': 36,
#     'learner_id': 'cb6wcvyn'},
#    237: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_lide8zdytr2_t2_sequenced.pkl',
#     'length': 16,
#     'learner_id': 'e8zdytr2'},
#    238: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0123_lidgyerx2d9_t2_sequenced.pkl',
#     'length': 63,
#     'learner_id': 'gyerx2d9'},
#    239: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lidew6cfr37_t2_sequenced.pkl',
#     'length': 65,
#     'learner_id': 'ew6cfr37'},
#    240: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2103_lidyez72a8b_t2_sequenced.pkl',
#     'length': 16,
#     'learner_id': 'yez72a8b'},
#    241: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0321_lid4rjjdez9_t2_sequenced.pkl',
#     'length': 35,
#     'learner_id': '4rjjdez9'},
#    242: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3021_lidm9u6p93a_t2_sequenced.pkl',
#     'length': 30,
#     'learner_id': 'm9u6p93a'},
#    243: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0312_lidtt5n8d2r_t2_sequenced.pkl',
#     'length': 70,
#     'learner_id': 'tt5n8d2r'},
#    244: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_lidtzpqpfaa_t2_sequenced.pkl',
#     'length': 24,
#     'learner_id': 'tzpqpfaa'},
#    245: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3120_lidke6msbfr_t2_sequenced.pkl',
#     'length': 39,
#     'learner_id': 'ke6msbfr'},
#    246: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_1320_lidfddsxudu_t2_sequenced.pkl',
#     'length': 63,
#     'learner_id': 'fddsxudu'},
#    247: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3210_lid22wyn9xy_t2_sequenced.pkl',
#     'length': 45,
#     'learner_id': '22wyn9xy'},
#    248: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2031_lidvqebanqv_t2_sequenced.pkl',
#     'length': 81,
#     'learner_id': 'vqebanqv'},
#    249: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lidzxp438xr_t2_sequenced.pkl',
#     'length': 28,
#     'learner_id': 'zxp438xr'},
#    250: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_3012_lidrjx9d3gf_t2_sequenced.pkl',
#     'length': 25,
#     'learner_id': 'rjx9d3gf'},
#    251: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0213_lid2xh9zuvc_t2_sequenced.pkl',
#     'length': 129,
#     'learner_id': '2xh9zuvc'},
#    252: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2013_lid7fj2vydr_t2_sequenced.pkl',
#     'length': 29,
#     'learner_id': '7fj2vydr'},
#    253: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2013_lidxngb9hff_t2_sequenced.pkl',
#     'length': 25,
#     'learner_id': 'xngb9hff'},
#    254: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_2013_lidsh6tu9g2_t2_sequenced.pkl',
#     'length': 60,
#     'learner_id': 'sh6tu9g2'},
#    255: {'path': '../data/sequenced_simulations/simplestate_secondslstm/p_0231_lids2up6gmm_t2_sequenced.pkl',
#     'length': 127,
#     'learner_id': 's2up6gmm'}},
#   'index': {'svdphyjs': 0,
#    '2ae6q3hw': 1,
#    '8jp62suc': 2,
#    'e93na59g': 3,
#    'chm4sr6j': 4,
#    'gc663sap': 5,
#    '8nh4zvcp': 6,
#    '7t9zwtmr': 7,
#    'wvxkvhne': 8,
#    '43e33t3h': 9,
#    'a3vdjxy9': 10,
#    'mkw5afyy': 11,
#    'dq4zzkyt': 12,
#    '5f4q4ng5': 13,
#    'temu2736': 14,
#    'f54jkrsw': 15,
#    'ujpk3gf4': 16,
#    'jkbx6axr': 17,
#    'vwfpuqaz': 18,
#    'w7asnymz': 19,
#    '2hr6mkdc': 20,
#    'nrxpa2ac': 21,
#    '5zrt4f8z': 22,
#    'm3d89p29': 23,
#    'vjr7tshm': 24,
#    'egg8756y': 25,
#    'uhbpoog9': 26,
#    'bg7x3db2': 27,
#    'xz56yha8': 28,
#    'rrykpeqz': 29,
#    '55yavcue': 30,
#    'p44vw7td': 31,
#    'fu6nsdhs': 32,
#    '2ejxq2u8': 33,
#    'ky8kttpv': 34,
#    'rdbqasqa': 35,
#    'zgyc948n': 36,
#    'c9dj36r7': 37,
#    'xvsgn53d': 38,
#    'qsd9cb5e': 39,
#    '9pjrsbth': 40,
#    'cp7mfn24': 41,
#    'j9qgkaej': 42,
#    '982cf4dn': 43,
#    '4zsmj6s3': 44,
#    '85pdk9mq': 45,
#    'hf8uz5t3': 46,
#    'k7p5eryf': 47,
#    'x844md8u': 48,
#    'baqyfz2h': 49,
#    '2ep3hayy': 50,
#    'jwntt96k': 51,
#    'wktpsvp8': 52,
#    'h75kp27p': 53,
#    '26z3wbqz': 54,
#    'x5sm9pfu': 55,
#    'mnhmyuhb': 56,
#    'tsrnkj8w': 57,
#    'uenn9vgu': 58,
#    '6h5vmwys': 59,
#    'ybxahrra': 60,
#    'u25vrfyy': 61,
#    'rgeb7wr9': 62,
#    'favvtnnf': 63,
#    'ntqpqkpq': 64,
#    'nj859xxh': 65,
#    'fh76v5qx': 66,
#    't6rjyw6s': 67,
#    'vhsgf3xa': 68,
#    'g6z8qykr': 69,
#    'rve4n5nv': 70,
#    '5h9umyr6': 71,
#    'v5w2e3zw': 72,
#    'nw65tu6j': 73,
#    'mhek2323': 74,
#    'rdy7sx9b': 75,
#    'tvtbbfhg': 76,
#    'caq55qe8': 77,
#    'drccqhk4': 78,
#    'tcnba4ca': 79,
#    'fs32fqe3': 80,
#    'r74r26kt': 81,
#    'e3b96acv': 82,
#    'ur9sxzx7': 83,
#    'uqven68r': 84,
#    'm35ub35g': 85,
#    'jx3yyy26': 86,
#    '5es5yqs8': 87,
#    'ydws5xx9': 88,
#    'wxz98urt': 89,
#    'qdp9ant4': 90,
#    '63xqh9t5': 91,
#    'beypwbck': 92,
#    'p6mkaa4e': 93,
#    'mwwddfvg': 94,
#    'uqw5vh3j': 95,
#    'uhq3p7yr': 96,
#    'p6269reg': 97,
#    'wnurkn96': 98,
#    'upp6pqmx': 99,
#    'bebyve9b': 100,
#    '3vsn2h9f': 101,
#    'v5gwycag': 102,
#    'uswb2jez': 103,
#    'nsj6k2rg': 104,
#    'w25mph3c': 105,
#    'upkt7qb4': 106,
#    'wbdyh5vk': 107,
#    'mp2aa258': 108,
#    'wpszzhxa': 109,
#    'uqzxsym7': 110,
#    'xw9qt6r4': 111,
#    'e22ppyf7': 112,
#    'xsxkdf7k': 113,
#    'yc3vmnuf': 114,
#    '84nmc3df': 115,
#    'unkrat9w': 116,
#    'ecy9k833': 117,
#    'urwu33jd': 118,
#    '4k4kc2k6': 119,
#    'r2q9q35x': 120,
#    'fryxwskq': 121,
#    '892r4czm': 122,
#    'aurjfgnn': 123,
#    'cdq4drkk': 124,
#    'p5t7d3sb': 125,
#    '4rhnvke9': 126,
#    'xpyjyx4m': 127,
#    'mzjq6z9t': 128,
#    'o9ffsiwt': 129,
#    'jydsy777': 130,
#    'xj86wyup': 131,
#    'edmrufua': 132,
#    '7xhcecye': 133,
#    '5m3ka2m2': 134,
#    'sx3vqc32': 135,
#    '4jchqv4d': 136,
#    'tsvcrpeg': 137,
#    '9p9gwu88': 138,
#    '6j6u2yct': 139,
#    'zs35fg8g': 140,
#    'h9t9mxtx': 141,
#    'bqmcqxyx': 142,
#    'ht865nws': 143,
#    'qk6q49f4': 144,
#    '39htvmt5': 145,
#    'mwfdr4ys': 146,
#    'xdxyjh8j': 147,
#    'jhrkm85q': 148,
#    '6tg95rzr': 149,
#    'sgsxmkfm': 150,
#    'fj5tdybn': 151,
#    'bezdgyya': 152,
#    'jwajupwj': 153,
#    '6z7nfy2j': 154,
#    'eb9iv6v2': 155,
#    '4bu2rkv3': 156,
#    'y9tk3ysm': 157,
#    'j6nndaxp': 158,
#    'nba9d6t2': 159,
#    's8w65sm5': 160,
#    'hkvk9vt9': 161,
#    'dubyutqd': 162,
#    'sgdgynxy': 163,
#    '3st3y5gc': 164,
#    'araav4jr': 165,
#    'sz8qvgyv': 166,
#    'suyrrcqe': 167,
#    '2xjmtbvz': 168,
#    'ytrbygud': 169,
#    '6fkbh35u': 170,
#    'v2cxb3a5': 171,
#    'ay2erc3c': 172,
#    '9bp6yz7m': 173,
#    'fm5rcvdy': 174,
#    'r29wzm6f': 175,
#    'y7p64n6z': 176,
#    '9aagpn4d': 177,
#    'sjz2rptd': 178,
#    'mcjaj2aj': 179,
#    'ujp9fgpn': 180,
#    'b72hbgvw': 181,
#    'evqzjs5p': 182,
#    'smqjhu44': 183,
#    'fyf6ag5v': 184,
#    'gvqh7qr2': 185,
#    'wger3sfa': 186,
#    '4k4dk9pu': 187,
#    'dbt5na3s': 188,
#    '2crhmbq7': 189,
#    'h543nsc8': 190,
#    'qkeyp2rg': 191,
#    'qsx2cc4b': 192,
#    '6uakv8nx': 193,
#    'b2q8ay65': 194,
#    'u6c3cp6c': 195,
#    '4vuc8rr3': 196,
#    '6bq62prp': 197,
#    'r78kg7d3': 198,
#    '47ce49e4': 199,
#    'qjfn2j8z': 200,
#    't3dwkezr': 201,
#    'q4z45p85': 202,
#    'szvqb37f': 203,
#    '9wdm7zue': 204,
#    'hrhu4yph': 205,
#    'g4xpwwac': 206,
#    '5y535ct3': 207,
#    'djnysnd6': 208,
#    's78drqcg': 209,
#    'fzagvhvf': 210,
#    's7mdq5tk': 211,
#    'sm8sfpcg': 212,
#    '5j7hdews': 213,
#    'zkrr45y5': 214,
#    '88kjzd8b': 215,
#    '4e438nww': 216,
#    '26mtbtye': 217,
#    'oikzz9af': 218,
#    'm749z8u9': 219,
#    'm4zvafhs': 220,
#    'd7777ske': 221,
#    'dmdc53tx': 222,
#    'gpq26qq9': 223,
#    '5a69aw4h': 224,
#    '4vtjgtja': 225,
#    'ryfqnvfh': 226,
#    '9sgu2tbg': 227,
#    'dk43m2pe': 228,
#    '9xc2v9vu': 229,
#    'jvxejtp9': 230,
#    'zgs84jfy': 231,
#    '8ethqmkd': 232,
#    '76wvaew4': 233,
#    'uthx49rq': 234,
#    'eau7bsmq': 235,
#    'cb6wcvyn': 236,
#    'e8zdytr2': 237,
#    'gyerx2d9': 238,
#    'ew6cfr37': 239,
#    'yez72a8b': 240,
#    '4rjjdez9': 241,
#    'm9u6p93a': 242,
#    'tt5n8d2r': 243,
#    'tzpqpfaa': 244,
#    'ke6msbfr': 245,
#    'fddsxudu': 246,
#    '22wyn9xy': 247,
#    'vqebanqv': 248,
#    'zxp438xr': 249,
#    'rjx9d3gf': 250,
#    '2xh9zuvc': 251,
#    '7fj2vydr': 252,
#    'xngb9hff': 253,
#    'sh6tu9g2': 254,
#    's2up6gmm': 255}}}

# %%
seed_data.keys()
# Out:
# dict_keys(['2022_03_03_7_15_30', '2022_03_03_0_15_30', '2022_03_03_9_15_30', '2022_03_03_11_15_30', '2022_03_03_8_15_30', '2022_03_03_1_15_30', '2022_03_03_6_15_30', '2022_03_03_10_15_30', '2022_03_03_12_15_30', '2022_03_03_3_15_30', '2022_03_03_4_15_30', '2022_03_03_14_15_30', '2022_03_03_13_15_30', '2022_03_03_5_15_30', '2022_03_03_2_15_30', '2022_03_03_7_45_61', '2022_03_03_0_45_61', '2022_03_03_9_45_61', '2022_03_03_11_45_61', '2022_03_03_8_45_61', '2022_03_03_1_45_61', '2022_03_03_6_45_61', '2022_03_03_10_45_61', '2022_03_03_12_45_61', '2022_03_03_15_45_61', '2022_03_03_3_45_61', '2022_03_03_4_45_61', '2022_03_03_14_45_61', '2022_03_03_13_45_61', '2022_03_03_5_45_61', '2022_03_03_2_45_61', '2022_03_03_7_30_45', '2022_03_03_0_30_45', '2022_03_03_9_30_45', '2022_03_03_11_30_45', '2022_03_03_8_30_45', '2022_03_03_1_30_45', '2022_03_03_6_30_45', '2022_03_03_10_30_45', '2022_03_03_12_30_45', '2022_03_03_3_30_45', '2022_03_03_4_30_45', '2022_03_03_14_30_45', '2022_03_03_13_30_45', '2022_03_03_5_30_45', '2022_03_03_2_30_45', '2022_03_03_7_1_15', '2022_03_03_0_1_15', '2022_03_03_9_1_15', '2022_03_03_11_1_15', '2022_03_03_8_1_15', '2022_03_03_1_1_15', '2022_03_03_6_1_15', '2022_03_03_10_1_15', '2022_03_03_12_1_15', '2022_03_03_3_1_15', '2022_03_03_4_1_15', '2022_03_03_13_1_15', '2022_03_03_5_1_15', '2022_03_03_2_1_15', 'all_data'])

# %%
roc_auc_score(seed_data['all_data']['y_test'], seed_data['all_data']['y_proba'])
# Out:
# 0.5035595035595035

# %%
roc_auc_score(seed_data['2022_03_03_7_15_30']['y_test'], [yp[1] for yp in seed_data['2022_03_03_7_15_30']['y_proba']])
# Out:
# 0.7484407484407485

# %%
seed_data.keys()
# Out:
# dict_keys(['60', '69', '5', '3', '75', '16', '64', '0', '96'])

# %%
seed_data['60'].keys()
# Out:
# dict_keys(['y_test', 'y_pred', 'y_proba', 'learner_ids', 'gender', 'language', 'field', 'year'])

# %%
seed_data['60']['learner_ids'].index('2hr6mkdc')
# Out:
# 3
