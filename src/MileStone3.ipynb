# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#ADA-Project:-MileStone3" data-toc-modified-id="ADA-Project:-MileStone3-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>ADA Project: MileStone3</a></span><ul class="toc-item"><li><span><a href="#While-way-finding-in-information-network,-is-human-a-Genius-or-a-Lazybone?" data-toc-modified-id="While-way-finding-in-information-network,-is-human-a-Genius-or-a-Lazybone?-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>While way-finding in information network, is human a <em>Genius</em> or a <em>Lazybone</em>?</a></span></li><li><span><a href="#Basic-analysis" data-toc-modified-id="Basic-analysis-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Basic analysis</a></span><ul class="toc-item"><li><span><a href="#Useful-libraries" data-toc-modified-id="Useful-libraries-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Useful libraries</a></span></li><li><span><a href="#Data-Importation" data-toc-modified-id="Data-Importation-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Data Importation</a></span></li><li><span><a href="#First-glance-at-the-data" data-toc-modified-id="First-glance-at-the-data-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>First glance at the data</a></span><ul class="toc-item"><li><span><a href="#Analyse-each-file-independently.-We-will-generate-more-datas-in-the-dataframe." data-toc-modified-id="Analyse-each-file-independently.-We-will-generate-more-datas-in-the-dataframe.-1.2.3.1"><span class="toc-item-num">1.2.3.1&nbsp;&nbsp;</span>Analyse each file independently. We will generate more datas in the dataframe.</a></span></li><li><span><a href="#Merge-Data-in-Files-together.-And-Analyse-the-Dataset-more-comprehensively" data-toc-modified-id="Merge-Data-in-Files-together.-And-Analyse-the-Dataset-more-comprehensively-1.2.3.2"><span class="toc-item-num">1.2.3.2&nbsp;&nbsp;</span>Merge Data in Files together. And Analyse the Dataset more comprehensively</a></span></li></ul></li></ul></li><li><span><a href="#LDA-topic-modeling" data-toc-modified-id="LDA-topic-modeling-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>LDA topic modeling</a></span><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Mathematics-Explanation:" data-toc-modified-id="Mathematics-Explanation:-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Mathematics Explanation:</a></span></li><li><span><a href="#LDA-text-preprocess" data-toc-modified-id="LDA-text-preprocess-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>LDA text preprocess</a></span></li></ul></li><li><span><a href="#Readability-Analysis" data-toc-modified-id="Readability-Analysis-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Readability Analysis</a></span><ul class="toc-item"><li><span><a href="#Mathematical-Equations" data-toc-modified-id="Mathematical-Equations-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Mathematical Equations</a></span><ul class="toc-item"><li><span><a href="#Flesch-reading-ease" data-toc-modified-id="Flesch-reading-ease-1.4.1.1"><span class="toc-item-num">1.4.1.1&nbsp;&nbsp;</span>Flesch reading-ease</a></span></li><li><span><a href="#Flesch-Kincaid-Grade-Level" data-toc-modified-id="Flesch-Kincaid-Grade-Level-1.4.1.2"><span class="toc-item-num">1.4.1.2&nbsp;&nbsp;</span>Flesch-Kincaid Grade Level</a></span></li><li><span><a href="#Dale-Chall-Readability" data-toc-modified-id="Dale-Chall-Readability-1.4.1.3"><span class="toc-item-num">1.4.1.3&nbsp;&nbsp;</span>Dale Chall Readability</a></span></li><li><span><a href="#Automated-Readability-Index-(ARI)" data-toc-modified-id="Automated-Readability-Index-(ARI)-1.4.1.4"><span class="toc-item-num">1.4.1.4&nbsp;&nbsp;</span>Automated Readability Index (ARI)</a></span></li><li><span><a href="#Coleman-Liau-Index" data-toc-modified-id="Coleman-Liau-Index-1.4.1.5"><span class="toc-item-num">1.4.1.5&nbsp;&nbsp;</span>Coleman Liau Index</a></span></li><li><span><a href="#Gunning-Fog" data-toc-modified-id="Gunning-Fog-1.4.1.6"><span class="toc-item-num">1.4.1.6&nbsp;&nbsp;</span>Gunning Fog</a></span></li></ul></li><li><span><a href="#Analysis-the-Readability-of-the-Link-that-People-Choose" data-toc-modified-id="Analysis-the-Readability-of-the-Link-that-People-Choose-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Analysis the Readability of the Link that People Choose</a></span><ul class="toc-item"><li><span><a href="#What-is-the-readability-of-sentences-which-include-the-high-frequency-path-pair?" data-toc-modified-id="What-is-the-readability-of-sentences-which-include-the-high-frequency-path-pair?-1.4.2.1"><span class="toc-item-num">1.4.2.1&nbsp;&nbsp;</span>What is the readability of sentences which include the high frequency path pair?</a></span></li><li><span><a href="#What-is-the-readability-distribution-over-sentences-which-include-different-clicking-frequency-of-links?" data-toc-modified-id="What-is-the-readability-distribution-over-sentences-which-include-different-clicking-frequency-of-links?-1.4.2.2"><span class="toc-item-num">1.4.2.2&nbsp;&nbsp;</span>What is the readability distribution over sentences which include different clicking frequency of links?</a></span></li></ul></li></ul></li><li><span><a href="#Position-Analysis" data-toc-modified-id="Position-Analysis-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Position Analysis</a></span><ul class="toc-item"><li><span><a href="#What-is-the-average-position-over-all-links-in-the-HTML-page?" data-toc-modified-id="What-is-the-average-position-over-all-links-in-the-HTML-page?-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>What is the average position over all links in the HTML page?</a></span></li><li><span><a href="#What-is-the-average-position-of-higher-clicking-frequency-links-in-the-HTML-page?" data-toc-modified-id="What-is-the-average-position-of-higher-clicking-frequency-links-in-the-HTML-page?-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>What is the average position of higher clicking frequency links in the HTML page?</a></span></li><li><span><a href="#What-is-the-distribution-of-position-over-Top-n%-clicked-links-in-HTML-page?" data-toc-modified-id="What-is-the-distribution-of-position-over-Top-n%-clicked-links-in-HTML-page?-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>What is the distribution of position over Top n% clicked links in HTML page?</a></span></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></li></ul></div>

# %% [markdown]
# # ADA Project: MileStone3

# %% [markdown]
# ## While way-finding in information network, is human a *Genius* or a *Lazybone*?

# %% [markdown]
# Navigation in the information network is an essential part of our everyday lives. It is significant to understand how humans build the link between two words, in order to design user-friendly interactive system. It is a general idea that: different from how a computer process the task, humans will not always choose the shortest path to reach destination. And at the first glance, one might consider that different people will link two words in various way according to their prior knowledge. However, here we want to investigate whether there is a common and general pattern in human’s formation of the word navigating. During the way-finding procedure, do human generate fantastic ideas to finish the word to word linking? Or though people finish the task in various path, there still exist a potential pattern in human’s mind to link two topic words. We carry out our analysis by using the dataset collecting through the human-computation game Wikispeedia.

# %% [markdown]
# Our main approach consists in analyzing the finished path during the game and delving into the contents in HTML pages which people scan in their navigation actions. The analysis part could be divided into two primary sections: research on the potential pattern included in the finished path (internal factor) and study whether the contents in HTML pages will influence people’s way-finding between the source and destination (external factor).

# %% [markdown]
# In the story, we will focus on the following research questions:
# 1.	Is there any specific pattern change in articles' topic component, during the clicking process? For example, when navigating from ‘Zebra’ to ‘French Revolution’, there is a hypothesis that the elements of animals may decrease, and the elements of history or politics would increase through the path. Does the ‘Zebra & French Revolution‘ hypothesis mentioned above or similar phenomenon hold?
# 2.	Are there any external factors that influence people’s choice of clicking, i.e. contents on HTML pages?
# 2.1	Do people tend to click links in an easy sentence or a professional sentence?
# 2.2	Do people tend to click links that show up in the first a few lines of the article or links that have concentrated distribution in the webpage?

# %% [markdown]
# We divide our project into three parts and each section answer one research question we put forward above.

# %% [markdown]
# ## Basic analysis
#
# First, we will do some basic analysis toward our dataset and answer the first question: Among all finished path in the game, which article do people often click on? Which path do people always follow?

# %% [markdown]
# ### Useful libraries

# %%
# Utilitaries
import pandas as pd
import os

# Math
import numpy as np
from scipy import stats
import statsmodels.api as sm
import operator

# Plot
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image
import matplotlib.colors as mcolors

# For LDA
import gensim
from gensim.utils import simple_preprocess
from gensim import corpora
from gensim.models import CoherenceModel
import spacy
nlp = spacy.load("en_core_web_sm", disable=['parser', 'ner'])
import pyLDAvis.gensim_models
from pprint import pprint
import re
from imp import reload

# For readability analysis
from readability import Readability
import nltk
import random
import os
from bs4 import BeautifulSoup
import urllib.parse
import statistics

import warnings
warnings.filterwarnings('ignore')
from imp import reload

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from IPython.display import Image

# %%
pd.options.mode.chained_assignment = None
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_colwidth', 100)

# %% [markdown]
# ### Data Importation

# %% [markdown]
# We will first import the data in file "paths_finished.tsv", "article.tsv", "categories.tsv" and "paths_finished.tsv" into DataFrame and we load "shortest-path-distance-matrix.txt" and store it as NxN matric where N is the number of the articles.

# %%
# Reading the 'paths_finished.tsv' file as a pandas dataframe
PATH_DATASET = "../dataset"
fname = os.path.join(PATH_DATASET, 'wikispeedia_paths-and-graph/paths_finished.tsv')
df_finished_path = pd.read_csv(fname, sep='\t', comment = '#', header=None, names = ['hashedIpAddress','timestamp','durationInSec','path','rating'], encoding = 'UTF-8')

# %%
# Reading the 'categories.tsv' file as a pandas dataframe

fname = os.path.join(PATH_DATASET, 'wikispeedia_paths-and-graph/categories.tsv')
df_categories = pd.read_csv(fname, sep = '\t', comment = '#', header = None, names = ['articles','category'], encoding = 'UTF-8')

# %%
# Reading the 'articles.tsv' file as a pandas dataframe

fname = os.path.join(PATH_DATASET, 'wikispeedia_paths-and-graph/articles.tsv')
df_article = pd.read_csv(fname, sep = '\t', comment = '#', header = None, names = ['articles'],encoding = 'UTF-8')

# %%
## Reading the 'paths_unfinished.tsv' file as a pandas dataframe

fname = os.path.join(PATH_DATASET, 'wikispeedia_paths-and-graph/paths_unfinished.tsv')
df_unfinished_path = pd.read_csv(fname, sep = '\t', comment = '#', header = None, names = ['hashedIpAddress','timestamp','durationInSec','path','target','type'],encoding = 'UTF-8')

# %%
## shortest path matrix

fname = os.path.join(PATH_DATASET, 'wikispeedia_paths-and-graph/shortest-path-distance-matrix.txt')
with open(fname, "r", encoding='utf-8') as f:
    txt_lines = [line.strip() for line in f.readlines()]
    del txt_lines[0:17]
shortest_dist_matrix = np.array(txt_lines)

# %% [markdown]
# ### First glance at the data

# %% [markdown]
# We first analyse each file, respectively. And then we will merge files together to delve more points.

# %% [markdown]
# #### Analyse each file independently. We will generate more datas in the dataframe.
# Files are "paths_finished.tsv" and "categories.tsv"

# %% [markdown]
# ##### **1. paths_finished.tsv**

# %% [markdown]
# Dataframe **df_finished_path** variables in this section
#
# `hashedIpAddress`: IP address in hashed format. It is the unique identifier.
#
# `timestamp`: timestamp when the game start. It is the unique identifier.
#
# `durationInSec`: time used by the player to finish the clicking task. Unit in second
#
# `path`: articles that player clicks during the game
#
# `rating`: score that the player get according to their path result
#
# `path_length`: length of the variable path
#
# `source`: the source article in the path
#
# `destination`: the target article in the path
#
# `path_pair`: article pair generated from the variable path

# %% [markdown]
# We calculate the path length and store the value in column **path_length**. For example if the path is "Yagan; Ancient_Egypt; Civilization", the path length is 2.

# %%
def calculate_path_length(x):
    string_array = x.split(';')
    return len(string_array)-1

df_finished_path['path_length'] = df_finished_path['path'].apply(calculate_path_length)

# %% [markdown]
# We extract the source and the target word from the path and store them in column **source** and **destination**, respectively.

# %%
def path_source(x):
    string_array = x.split(';')
    return string_array[0]


def path_destination(x):
    string_array = x.split(';')
    return string_array[-1]

df_finished_path['source'] = df_finished_path['path'].apply(path_source)
df_finished_path['destination'] = df_finished_path['path'].apply(path_destination)

# %% [markdown]
# We construct the data "path pair". For example, if the path is "A; B; C", then the path pair will be [(A, B), (B, C)]

# %%
df_finished_path['path_pair'] = None

i = 0
path_pair_dict = {}
for index, row in df_finished_path['path'].items():
    string_path_pair = []
    string_array = row.split(";")
    for pair_index in range(len(string_array) - 1):
        string_pair = '(' + string_array[pair_index] + ', ' + string_array[pair_index + 1] + ')'
        string_path_pair.append(string_pair)
        path_pair_dict[string_pair] = path_pair_dict.get(string_pair, 0) + 1
    df_finished_path['path_pair'][i] = string_path_pair
    i += 1

# %%
df_finished_path.head(5)
# Out:
#     hashedIpAddress   timestamp  durationInSec                                                                                                 path  rating  path_length        source          destination                                                                                            path_pair
# 0  6a3701d319fc3754  1297740409            166  14th_century;15th_century;16th_century;Pacific_Ocean;Atlantic_Ocean;Accra;Africa;Atlantic_slave_...     NaN            8  14th_century  African_slave_trade  [(14th_century, 15th_century), (15th_century, 16th_century), (16th_century, Pacific_Ocean), (Pac...
# 1  3824310e536af032  1344753412             88                                  14th_century;Europe;Africa;Atlantic_slave_trade;African_slave_trade     3.0            4  14th_century  African_slave_trade  [(14th_century, Europe), (Europe, Africa), (Africa, Atlantic_slave_trade), (Atlantic_slave_trade...
# ...

# %% [markdown]
# Analyze the data in dataframe df_finished_path

# %% [markdown]
# ##### Variable: path length

# %% [markdown]
# First, we anlyse the variable path_length. We draw the histogram of it.

# %%
df_finished_path['path_length'].plot.hist(bins=np.arange(-0.5,440.5, 10), edgecolor='white', logy=True)
plt.xlabel("Path Length")
plt.ylabel("Count")
plt.title("Path Length Frequency Histogram")
# Out:
# Text(0.5, 1.0, 'Path Length Frequency Histogram')

# %% [markdown]
# From the histogram, we could find that the path length mainly concentrates on the range(0, 100). There is also one outlier lying at 400+. In order to remove the special situations during the game playing, we set the range of bins to 10. And we consider that the path length frequency in each bin, which is smaller than 2, as outliers. We remove the path length larger than 100.

# %%
df_finished_path_rm_outlier = df_finished_path[df_finished_path['path_length'] <= 100]

# %% [markdown]
# We also find there are data whose path_length equals to 0. It means that the target article is same to to source one or people can directly find the target word in the source article. It is hard to distinguish the situation between whether the player is fortunate enough or connect two words by their own ability. Therefore, we consider to remove those data whose path_length equals to 0.

# %%
df_finished_path_rm_outlier = df_finished_path_rm_outlier[df_finished_path_rm_outlier['path_length'] != 0]

# %% [markdown]
# Then we draw the histogram again.

# %%
df_finished_path_rm_outlier['path_length'].plot.hist(bins=np.arange(-0.5,100.5,1), edgecolor='white', logy=True)
plt.xlabel("Path Length")
plt.ylabel("Count")
plt.title("Path Length Frequency Histogram without Outliers")
# Out:
# Text(0.5, 1.0, 'Path Length Frequency Histogram without Outliers')

# %% [markdown]
# ##### Variable: rating and path_length

# %% [markdown]
# As we calculated the path lengths, we also want to find that whether the rate is related to the path length. We create a new Dataframe to store the rated paths.

# %%
## Is rating related to steps?

# use only data with rating
df_rate = df_finished_path_rm_outlier[df_finished_path_rm_outlier['rating']>0]

# %% [markdown]
# We draw the boxplot with the variable data path_length and rating.

# %%
print('Average steps for each rating')
for i in range(5):
    # calculate the intervals
    CI = stats.norm.interval(0.95, np.mean(df_rate[df_rate.rating == i+1].path_length), np.std(df_rate[df_rate.rating == i+1].path_length)/np.sqrt(len(df_rate[df_rate.rating == i+1].path_length)))
    print('rating =',i+1)
    print('number:',df_rate[df_rate.rating == i+1].path_length.count())
    print('mean:',df_rate[df_rate.rating == i+1].path_length.mean(),'\n95% CI:',CI)
# Out:
# Average steps for each rating
# rating = 1
# number: 8542
# mean: 3.6661203465230625
# 95% CI: (3.6225986640558583, 3.7096420289902667)
# rating = 2
# number: 8792
# mean: 5.001592356687898
# 95% CI: (4.950619800250819, 5.052564913124978)
# rating = 3
# number: 7261
# mean: 6.645503374190882
# 95% CI: (6.560040894779702, 6.730965853602063)
# rating = 4
# number: 2748
# mean: 9.08296943231441
# 95% CI: (8.863767675989052, 9.302171188639768)
# rating = 5
# number: 1156
# mean: 11.852941176470589
# 95% CI: (11.184158085458863, 12.521724267482314)

# %%
# df_rate.plot.scatter(x='steps', y='rating')
df_rate.boxplot(column=['path_length'], by=['rating'])
plt.xlabel("rating")
plt.ylabel("path_length")
plt.title("Boxplot of Path Length and Rating")
# Out:
# Text(0.5, 1.0, 'Boxplot of Path Length and Rating')

# %% [markdown]
# From the above plot, we find that the rating is related to the path length. And then we do the linear regression toward the rating and path length.

# %%
Xtrain = df_rate['rating']
ytrain = df_rate['path_length']

Xtrain = sm.add_constant(Xtrain)

model = sm.OLS(ytrain, Xtrain).fit()

print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            path_length   R-squared:                       0.210
# Model:                            OLS   Adj. R-squared:                  0.210
# Method:                 Least Squares   F-statistic:                     7566.
# Date:                Fri, 23 Dec 2022   Prob (F-statistic):               0.00
# Time:                        16:45:12   Log-Likelihood:                -79516.
# No. Observations:               28499   AIC:                         1.590e+05
# Df Residuals:                   28497   BIC:                         1.591e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5414      0.053     29.020      0.000       1.437       1.646
# ...

# %% [markdown]
# ##### **2. categories.tsv**

# %% [markdown]
# Dataframe **df_categories** variables
#
# `articles`: the name of the article
#
# `category`: the category that the article belongs to
#
# `category_length`: the hierarchical depth of the variable category
#
# `category_1st`: the 1st category that the article belongs to

# %% [markdown]
# We calculate the hierarchical depth of variable category

# %%
def calculate_category_length(x):
    string_array = x.split('.')
    return len(string_array)

df_categories['category_length'] = df_categories['category'].apply(calculate_category_length)

# %% [markdown]
# Since all of the articles with categories have the same root 'Subject', we firstly extract the 1st depth category and store the data in the column **category_1st**

# %%
df_categories['category_1st'] = df_categories.apply(lambda x:x.category.split('.')[1], axis = 1)

# %% [markdown]
# Analyze the data in dataframe df_categories

# %% [markdown]
# ##### Variable: category_length

# %% [markdown]
# We first count the frequency according to the variable category_length. There are 274 articles which category depth equals to 2. And 3448 articles which category depth equals to 3. And 1482 articles which category depth equals to 4.

# %%
df_categories['category_length'].value_counts()
# Out:
# 3    3448
# 4    1482
# 2     274
# Name: category_length, dtype: int64

# %% [markdown]
# Then, we check the category with different depth in details.

# %%
category_dict_1 = {}
category_dict_2 = {}
category_dict_3 = {}

for index, row in df_categories['category'].items():
    string_path_pair = []
    string_array = row.split(".")
    for index in range(len(string_array)):
        if index == 1:
            category_dict_1[string_array[index-1] + "." + string_array[index]] = category_dict_1.get(string_array[index-1] + "." + string_array[index], 0) + 1
        elif index == 2:
            category_dict_2[string_array[index-2] + "." + string_array[index-1] + "." + string_array[index]] = category_dict_2.get(string_array[index-2] + "." + string_array[index-1] + "." + string_array[index], 0) + 1
        elif index == 3:
            category_dict_3[string_array[index-3] + "." + string_array[index-2] + "." + string_array[index-1] + "." + string_array[index]] = category_dict_3.get(string_array[index-3] + "." + string_array[index-2] + "." + string_array[index-1] + "." + string_array[index], 0) + 1

# %% [markdown]
# We check the categories at the depth 1. Key is the category and the value is the number of articles in this cateogory.

# %%
print("There are {} categories at depth 1".format(len(category_dict_1)))
for i, (k,v) in enumerate(category_dict_1.items()):
    if i < 10:
        print({k: v},end="\n")
# Out:
# There are 15 categories at depth 1
# {'subject.History': 545}
# {'subject.People': 689}
# {'subject.Countries': 229}
# {'subject.Geography': 1084}
# {'subject.Business_Studies': 88}
# {'subject.Science': 1122}
# {'subject.Everyday_life': 374}
# {'subject.Design_and_Technology': 254}
# {'subject.Music': 97}
# {'subject.IT': 85}

# %% [markdown]
# We check the categories at the depth 2. Key is the category and the value is the number of articles in this cateogory.

# %%
print("There are {} categories at depth 2".format(len(category_dict_2)))
for i, (k,v) in enumerate(category_dict_2.items()):
    if i < 10:
        print({k: v},end="\n")
# Out:
# There are 103 categories at depth 2
# {'subject.History.British_History': 158}
# {'subject.People.Historical_figures': 108}
# {'subject.Geography.European_Geography': 139}
# {'subject.People.Artists': 36}
# {'subject.Business_Studies.Currency': 14}
# {'subject.History.General_history': 80}
# {'subject.History.Military_History_and_War': 71}
# {'subject.Science.Physics': 226}
# {'subject.Everyday_life.Sports_events': 22}
# {'subject.Geography.Storms': 33}

# %% [markdown]
# We check the categories at the depth 3. Key is the category and the value is the number of articles in this cateogory.

# %%
print("There are {} categories at depth 3".format(len(category_dict_3)))
for i, (k,v) in enumerate(category_dict_3.items()):
    if i < 10:
        print({k: v},end="\n")
# Out:
# There are 27 categories at depth 3
# {'subject.History.British_History.British_History_1500_and_before_including_Roman_Britain': 73}
# {'subject.Geography.European_Geography.European_Countries': 56}
# {'subject.Science.Physics.Space_Astronomy': 105}
# {'subject.Science.Biology.Health_and_medicine': 109}
# {'subject.Science.Physics.General_Physics': 55}
# {'subject.Science.Biology.Mammals': 114}
# {'subject.Science.Biology.Plants': 108}
# {'subject.History.British_History.British_History_15001750': 29}
# {'subject.Geography.Geography_of_Asia.Asian_Countries': 37}
# {'subject.Geography.Geography_of_the_Middle_East.Middle_Eastern_Countries': 18}

# %% [markdown]
# ##### Variable: categories

# %% [markdown]
# We will carry out some basic analysis to the variable category.

# %%
## how many categories are there in the dataframe

category_list = df_categories['category'].value_counts()
plt.hist(category_list, 150)
plt.xlabel("Article numbers in one category")
plt.ylabel("Frequency")
plt.title('Frequency of Articles in One Category')
category_list[:10]
# Out:
# subject.Countries                               229
# subject.Science.Biology.Birds                   161
# subject.Geography.Geography_of_Great_Britain    124
# subject.Science.Chemistry.Chemical_elements     119
# subject.Science.Biology.Mammals                 114
# subject.Science.Biology.Health_and_medicine     109
# subject.Science.Biology.Plants                  108
# subject.People.Historical_figures               108
# subject.Science.Physics.Space_Astronomy         105
# subject.Geography.North_American_Geography      103
# Name: category, dtype: int64

# %% [markdown]
# ##### **3. articles.tsv**

# %% [markdown]
# Dataframe **df_article_with_cate** variables
#
# `articles`: the name of the article
#
# `category`: the category that the article belongs to
#
# `category_length`: the hierarchical depth of the variable category
#
# `category_1st`: the 1st category that the article belongs to

# %% [markdown]
# We mainly used this file to get the index of an article.
# However, we can also anylize the articles by combining with categories.

# %%
## label every article with category

df_article_with_cate = pd.merge(df_article, df_categories, how = 'outer')
df_article_with_cate.head()
# Out:
#                            articles                                                                                 category  category_length category_1st
# 0  %C3%81ed%C3%A1n_mac_Gabr%C3%A1in  subject.History.British_History.British_History_1500_and_before_including_Roman_Britain              4.0      History
# 1  %C3%81ed%C3%A1n_mac_Gabr%C3%A1in                                                        subject.People.Historical_figures              3.0       People
# 2                        %C3%85land                                                                        subject.Countries              2.0    Countries
# 3                        %C3%85land                                  subject.Geography.European_Geography.European_Countries              4.0    Geography
# 4                %C3%89douard_Manet                                                                   subject.People.Artists              3.0       People

# %%
# find articles without categories
df_article_with_cate[df_article_with_cate.isnull().T.any()]
# Out:
#                      articles category  category_length category_1st
# 1360              Directdebit      NaN              NaN          NaN
# 1385                 Donation      NaN              NaN          NaN
# 1811       Friend_Directdebit      NaN              NaN          NaN
# 3670                  Pikachu      NaN              NaN          NaN
# 4342  Sponsorship_Directdebit      NaN              NaN          NaN
# 5141              Wowpurchase      NaN              NaN          NaN

# %%
# find articles with multiple categories
dup_cate_list = df_article_with_cate.articles.value_counts()

# modify no category articles
dup_cate_list[df_article_with_cate[df_article_with_cate.isnull().T.any()].articles] = 0

dup_cate_list.hist()
plt.yscale('log')
plt.xlabel("Article categories")
plt.ylabel("Frequency")
plt.title('Frequency of Category Number of One Article')
plt.show()

# %% [markdown]
# ##### **4. paths_unfinished.tsv**

# %% [markdown]
# Dataframe **paths_unfinished** variables in this section
#
# `hashedIpAddress`: IP address in hashed format. It is the unique identifier.
#
# `timestamp`: timestamp when the game start. It is the unique identifier.
#
# `durationInSec`: time used by the player to finish the clicking task. Unit in second
#
# `path`: articles that player clicks during the game
#
# `target`: the target article in the path
#
# `type`: reason why the path is not finish
#
# `path_length`: length of the path

# %% [markdown]
# We mainly analyze the unfinished paths by focusing on the quit type, path length and its target.

# %%
# different number of reason for unfinished
df_unfinished_path.type.value_counts()
# Out:
# restart    15552
# timeout     9323
# Name: type, dtype: int64

# %%
# count path lengths
df_unfinished_path['path_length'] = df_unfinished_path.apply(lambda x:x.path.count(';'),axis = 1)

# %% [markdown]
# Find out players restart without clicking any links

# %%
df_restart0 = df_unfinished_path[(df_unfinished_path.type == 'restart') & (df_unfinished_path.path_length == 0)]
df_restart0.head()
# Out:
#      hashedIpAddress   timestamp  durationInSec             path            target     type  path_length
# 3   53a53bc244e08a6a  1297094761             49         Paraguay  Mount_St._Helens  restart            0
# 8   6d136e371e42474f  1297102100             19            Logic      Moon_landing  restart            0
# 11  05dc2fbd5fc8d375  1297135100              8          Niobium      Beeching_Axe  restart            0
# 15  5900aa2d71b99153  1297138883             22  Prostate_cancer             Du_Fu  restart            0
# 20  3786d9852b814082  1297152708             13   Snowball_Earth    Medal_of_Honor  restart            0

# %%
plt.hist(df_restart0.durationInSec,100)
plt.yscale('log')
plt.xlabel("Duration in Seconds")
plt.ylabel("Frequency")
plt.title('Frequency of the Playing Duration')
plt.show()

# %% [markdown]
# We can see that most of players they quit without carefully viewing the article while a few players they might have read the article and then deciede to restart.

# %% [markdown]
# Then we can have a look on the target: with which target players are more likely to quit?

# %%
restart0_target_list = pd.DataFrame(data = df_restart0.target.value_counts(sort = True))
restart0_target_list = restart0_target_list[restart0_target_list.target > 10]
restart0_target_list[:10]
# Out:
#                 target
# Telephone          113
# Zebra              105
# Viking              66
# Bean                62
# Adolf_Hitler        26
# Microsoft           19
# Penguin             16
# Wood                13
# Krazy_Kat           12
# Social_capital      12

# %% [markdown]
# Take the target show up frequency into consideration

# %%
restart0_target_list_total = pd.DataFrame(df_unfinished_path[df_unfinished_path['target'].isin(restart0_target_list.index)].target.value_counts(sort = True))
restart0_target_ratio = restart0_target_list/restart0_target_list_total
restart0_target_ratio.sort_values(by=['target'])
# Out:
#                     target
# Tiger_Woods       0.050459
# Bean              0.065263
# Viking            0.089918
# Telephone         0.106604
# Zebra             0.117581
# Wood              0.139785
# Banana            0.142857
# Google            0.148148
# Krazy_Kat         0.173913
# The_Country_Wife  0.239130
# God               0.244444
# Microsoft         0.263889
# Social_capital    0.272727
# Adolf_Hitler      0.276596
# Penguin           0.372093

# %% [markdown]
# It seems players are more likely to quit when they see Penguin as target.

# %% [markdown]
# All the above analysis focus more on seperate files and aim at giving a first impression of the datasets.

# %% [markdown]
# #### Merge Data in Files together. And Analyse the Dataset more comprehensively

# %% [markdown]
# ##### Convert path to index number format
# ```bash
# A. Convert path to index number format
# ```

# %% [markdown]
# We merge the category and article file together.

# %%
df_article_merge = df_article.copy(deep=True)
df_article_merge.index.name = "temp"
df_temp = df_article.reset_index(drop=True)
df_merge_category_article = pd.merge(df_temp, df_categories, how = 'outer')
df_merge_category_article.head()
# Out:
#                            articles                                                                                 category  category_length category_1st
# 0  %C3%81ed%C3%A1n_mac_Gabr%C3%A1in  subject.History.British_History.British_History_1500_and_before_including_Roman_Britain              4.0      History
# 1  %C3%81ed%C3%A1n_mac_Gabr%C3%A1in                                                        subject.People.Historical_figures              3.0       People
# 2                        %C3%85land                                                                        subject.Countries              2.0    Countries
# 3                        %C3%85land                                  subject.Geography.European_Geography.European_Countries              4.0    Geography
# 4                %C3%89douard_Manet                                                                   subject.People.Artists              3.0       People

# %% [markdown]
# We can find there are several articles which do not have any category. (-1 is the sign of withdraw '<', we will not delete it)

# %%
df_merge_category_article[df_merge_category_article.isnull().T.any()]
# Out:
#                      articles category  category_length category_1st
# 1360              Directdebit      NaN              NaN          NaN
# 1385                 Donation      NaN              NaN          NaN
# 1811       Friend_Directdebit      NaN              NaN          NaN
# 3670                  Pikachu      NaN              NaN          NaN
# 4342  Sponsorship_Directdebit      NaN              NaN          NaN
# 5141              Wowpurchase      NaN              NaN          NaN

# %% [markdown]
# We will drop all rows which has the above articles in the path, in order to finish the later category analysis.

# %%
delete_words = ["Directdebit", "Donation", "Friend_Directdebit", "Pikachu", "Sponsorship_Directdebit", "Wowpurchase"]
for delete_word in delete_words:
    drop_temp_index = df_finished_path_rm_outlier[df_finished_path_rm_outlier['path'].str.contains(delete_word)].index
    df_finished_path_rm_outlier = df_finished_path_rm_outlier.drop(drop_temp_index, axis=0)

# %% [markdown]
# The path will be converted to number index in the column **pathnum**. We can first use the index to get the shortest path and make comparison. Also, this is useful when we later analyze in LDA construction.

# %%
## First modify the df_article to make it easier find index
# record index and change index to articles names
df_article_temp = df_article.copy(deep = True)
df_article_temp['num'] = df_article.index
df_article_temp.index = df_article['articles']

## add withdraw step '<' as 'article: -1'
df_article_temp.loc['<'] = -1

# %%
df_finished_path_rm_outlier['pathnum'] = df_finished_path_rm_outlier.apply(lambda x:df_article_temp.loc[x.path.split(';')[:]].num.tolist(), axis = 1)

# %%
df_finished_path_rm_outlier[['path','pathnum']].head()
# Out:
#                                                                                                   path                                      pathnum
# 0  14th_century;15th_century;16th_century;Pacific_Ocean;Atlantic_Ocean;Accra;Africa;Atlantic_slave_...  [10, 12, 15, 3134, 377, 105, 128, 379, 143]
# 1                                  14th_century;Europe;Africa;Atlantic_slave_trade;African_slave_trade                    [10, 1433, 128, 379, 143]
# 2    14th_century;Niger;Nigeria;British_Empire;Slavery;Africa;Atlantic_slave_trade;African_slave_trade   [10, 2982, 2984, 694, 3755, 128, 379, 143]
# 3                                                       14th_century;Renaissance;Ancient_Greece;Greece                        [10, 3464, 241, 1793]
# 4  14th_century;Italy;Roman_Catholic_Church;HIV;Ronald_Reagan;President_of_the_United_States;John_F...     [10, 2183, 3529, 1836, 3542, 3342, 2266]

# %% [markdown]
# With paths represent in numbers, we can also compare the length of the path with the shortest path length.

# %%
# add shortest path length to dataframe
df_finished_path_rm_outlier['shortest'] = df_finished_path_rm_outlier.apply(lambda x:shortest_dist_matrix[x['pathnum'][0]][x['pathnum'][-1]], axis = 1)

# temporately not consider the error in shortest path
df_finished_path_rm_outlier = df_finished_path_rm_outlier.drop(df_finished_path_rm_outlier[df_finished_path_rm_outlier['shortest'] == '_'].index, axis = 0)
# use 'int' type in shortest path length instead of 'string'
df_finished_path_rm_outlier['shortest'] = df_finished_path_rm_outlier.apply(lambda x: int(x.shortest), axis = 1)

# visualize
plt.scatter(df_finished_path_rm_outlier['shortest'], df_finished_path_rm_outlier['path_length'],alpha=0.5)
plt.xlabel('Shortest Path Length')
plt.xlabel('Real Path Length')
plt.title('Compare the shortest path length with the real path length in the game')
# Out:
# Text(0.5, 1.0, 'Compare the shortest path length with the real path length in the game')

# %% [markdown]
# ##### Analyze the finished_path dataframe joined with categories
# ```bash
# B. Analyze the finished_path dataframe joined with categories
# ```

# %% [markdown]
# Dataframe **df_finished_path_rm_outlier** variables
#
# `hashedIpAddress`: IP address in hashed format. It is the unique identifier.
#
# `timestamp`: timestamp when the game start. It is the unique identifier.
#
# `durationInSec`: time used by the player to finish the clicking task. Unit in second
#
# `path`: articles that player clicks during the game
#
# `rating`: score that the player get according to their path result
#
# `path_length`: length of the variable path
#
# `source`: the source article in the path
#
# `destination`: the target article in the path
#
# `path_pair`: article pair generated from the variable path
#
# `pathnum`: convert the path to path number index
#
# `first_path`: article that the user first click on
#
# `first_path_category`: category of the article that the user first click on
#
# `first_path_category_length`: length of the variable first_path_category
#
# `first_path_category_1st`: 1st category of the article that the user first click on
#
# `source_category`: category of the source article
#
# `source_category_length`: length of the variable source_category
#
# `source_category_1st`: 1st category of the source article
#
# `dest_category`: category of the destination article
#
# `dest_category_length`: length of the variable dest_category
#
# `dest_category_1st`: 1st category of the destination article
#
# `source_dest_category_1st`: category pairs contain the category of source and destination articles
#
# `source_first_path_category_1st`: category pairs contain the category of source and first clicking articles

# %% [markdown]
# We begin our investigation by counting the basic statistical results from the dataset. We focus on the finished path and try to find whether there is an article selection tendency in people’s playing procedure. The section will be divided into two parts. In the first part, we will investigate which kind of article do people select in their first step. In the second part, we study on the finished path in details. We introduce the term “path pair” and carry out the statistical analysis on which path pair do people often choose.

# %% [markdown]
# First merge the df_finished_path and df_categories. Every data about the articles will have their category information.
# First, we extract the first article that the user click and store the data in column **first_path**

# %%
df_merge_finished_path_category = df_finished_path_rm_outlier.copy(deep=True)
df_merge_finished_path_category['first_path'] = df_merge_finished_path_category.apply(lambda x:x.path.split(';')[1], axis = 1)

# %% [markdown]
# We merge the path and the category dataframe together. We create new columns called "first_category" and "first_category_length" to store the category information of the first path

# %%
df_merge_finished_path_category = pd.merge(df_merge_finished_path_category, df_categories, left_on='first_path', right_on='articles')

# %%
df_merge_finished_path_category['first_path_category'] = df_merge_finished_path_category['category']
df_merge_finished_path_category['first_path_category_length'] = df_merge_finished_path_category['category_length']
df_merge_finished_path_category['first_path_category_1st'] = df_merge_finished_path_category.apply(lambda x:x.first_path_category.split('.')[1], axis = 1)
df_merge_finished_path_category = df_merge_finished_path_category.drop(['category','articles', 'category_length', 'category_1st'], axis = 1)

# %% [markdown]
# We create new columns called "source_category" and "source_category_length" to store the category information of the source article. We create new columns called "dest_category" and "dest_category_length" to store the category information of the destination article.

# %%
df_merge_finished_path_category = pd.merge(df_merge_finished_path_category, df_categories,left_on='source', right_on='articles')
df_merge_finished_path_category['source_category'] = df_merge_finished_path_category['category']
df_merge_finished_path_category['source_category_length'] = df_merge_finished_path_category['category_length']
df_merge_finished_path_category['source_category_1st'] = df_merge_finished_path_category.apply(lambda x:x.source_category.split('.')[1], axis = 1)
df_merge_finished_path_category = df_merge_finished_path_category.drop(['category','articles', 'category_length', 'category_1st'], axis = 1)

df_merge_finished_path_category = pd.merge(df_merge_finished_path_category, df_categories,left_on='destination', right_on='articles')
df_merge_finished_path_category['dest_category'] = df_merge_finished_path_category['category']
df_merge_finished_path_category['dest_category_length'] = df_merge_finished_path_category['category_length']
df_merge_finished_path_category['dest_category_1st'] = df_merge_finished_path_category.apply(lambda x:x.dest_category.split('.')[1], axis = 1)
df_merge_finished_path_category = df_merge_finished_path_category.drop(['category','articles', 'category_length', 'category_1st'], axis = 1)

# %% [markdown]
# Then, we merge the source category with the destination category and store the data in column **source_dest_category**

# %%
df_merge_finished_path_category['source_dest_category_1st'] = df_merge_finished_path_category['source_category_1st'].str.cat(';' + df_merge_finished_path_category['dest_category_1st'])

# %%
df_merge_finished_path_category['source_dest_category'] = df_merge_finished_path_category['source_category'].str.cat(';' + df_merge_finished_path_category['dest_category'])

# %% [markdown]
# Then, we merge the source category with the first path category and store the data in column **source_first_path_category**

# %%
df_merge_finished_path_category['source_first_path_category_1st'] = df_merge_finished_path_category['source_category_1st'].str.cat(';' + df_merge_finished_path_category['first_path_category_1st'])

# %%
df_merge_finished_path_category.head()
# Out:
#     hashedIpAddress   timestamp  durationInSec                                                                                                 path  rating  path_length        source          destination                                                                                            path_pair                                      pathnum  shortest    first_path                                    first_path_category  first_path_category_length first_path_category_1st                             source_category  source_category_length source_category_1st                    dest_category  dest_category_length dest_category_1st source_dest_category_1st                                                        source_dest_category source_first_path_category_1st
# ...

# %% [markdown]
# Analyze the data in dataframe df_merge_finished_path_category

# %% [markdown]
# ##### Variable: first_path_category_1st

# %% [markdown]
# In the dataset, each article has its own belonging category, and the category is in hierarchical form with the deepest depth reaches 3rd layer. For example, the word “Albatross” belongs to category “subject.Science.Biology.Birds”. For simplicity, we only use the second layer as their category in our analysis. Therefore, there are 15 article categories in total in the dataset.

# %% [markdown]
# We count the frequency of variable **first_path_category_1st**. For example, the result shows that the first clicking article which is in the Science category is 13672 times among the whole finished path.

# %%
click_category_count_depth1 = df_merge_finished_path_category['first_path_category_1st'].value_counts(sort = True).sort_index()
click_category_count_depth1
# Out:
# Art                          360
# Business_Studies            1076
# Citizenship                 4066
# Countries                  17662
# Design_and_Technology       1062
# Everyday_life               3841
# Geography                  35067
# History                     6959
# IT                          1235
# Language_and_literature     3133
# Mathematics                  403
# Music                        479
# People                      3094
# Religion                    2119
# Science                    13672
# Name: first_path_category_1st, dtype: int64

# %% [markdown]
# Then, we compare the result above with the article numbers in each category. For example, there are 38 articles in the category Art. And when people play the game, there are 360 times that people choose the Art category in their first choice.

# %%
y = range(len(click_category_count_depth1))
catagory_values = df_categories['category_1st'].value_counts(sort = True).sort_index()

rects1 = plt.barh(y=y, width=click_category_count_depth1, height=0.4, alpha=0.8, color='red', label="click number")
rects2 = plt.barh(y=[i + 0.4 for i in y], width=catagory_values, height=0.4, color='green', label="article number")

plt.xlabel("numbers")

plt.yticks([index + 0.4 for index in y], click_category_count_depth1.index)
plt.ylabel("categories")
plt.title("First step")
plt.legend()

for rect in rects1:
    width = rect.get_width()
    plt.text(width, rect.get_y() + rect.get_height() / 2 - 0.2, str(width))
for rect in rects2:
    width = rect.get_width()
    plt.text(width, rect.get_y() + rect.get_height() / 2 - 0.1, str(width))
plt.show()

# %% [markdown]
# Besides counting the number of clicking on the first articles, we also include the number of articles in each category in the picture. We consider that the article number in one category will also influence people’s clicking behavior and the normalization is necessary. For example, the clicking on articles belongs to Science is 13672 times while the amount of articles in this category is also large (1122 articles). As a consequence, we calculate the ratio of each category and draw the statistical diagram again.

# %% [markdown]
# We draw the picture which shows the ratio of article numbers in each category and the times that people choose article in this kind of category in their first choice.

# %%
# ratio

rects3 = plt.barh(y=y, width = round(click_category_count_depth1/catagory_values,2), height=0.4, alpha=0.8, color='blue', label="ratio")
plt.xlabel("ratio")

plt.yticks([index  for index in y], click_category_count_depth1.index)
plt.ylabel("categories")
plt.title("First step")
plt.legend()

for rect in rects3:
    width = rect.get_width()
    plt.text(width, rect.get_y() + rect.get_height() / 2 -0.2, str(width))

plt.show()

# %% [markdown]
# From the above results, we draw to the conclusion that people tend to select articles belong to category Countries and Geography in their first step. The ratio is far larger than the other categories. We speculate the reason is that people are more familiar with the Countries and Geography information of the target words. It is a general approach of getting closer to the destination via moving to articles that have similar geographic location and country information. Take the word “panda” for instance. When people are required to navigate to this target, people should first click to articles that include China or Asia elements. Hence, the Countries and Geography information could help people step closer to their target quickly which leads to the high ratio results of category Countries and Geography in the above diagram. And this is a possible linking pattern exist in the game.

# %% [markdown]
# From the picture, we find that the ratio of category Countries and Geography is relatively high, comparing with other categories. It means that people tends to click on the article with category "Countries" and "Geography" in their first clicking choice.
# Then in the later project, we would focus on the HTML in Countries and Geography category to find the reason why people tends to choose this kind of article.

# %% [markdown]
# ##### Variable: source_first_path_category

# %% [markdown]
# Then, we get the statistic of category pairs. The category pairs contains the category of source articles and the category of articles that people choose first in their clicking process. We can get a overview of the top10 category links. Also, this is affect by the number of articles in the categories. We can further analyze with this in the future.

# %%
click_category_count_depth1_source_first_path = df_merge_finished_path_category['source_first_path_category_1st'].value_counts(sort = True)
click_category_count_depth1_source_first_path[0:10]
# Out:
# Science;Science                      8987
# Geography;Geography                  8521
# Science;Geography                    6213
# People;Geography                     3848
# Everyday_life;Geography              3586
# Geography;Countries                  3558
# History;Geography                    2968
# Science;Countries                    2763
# Countries;Geography                  2158
# Language_and_literature;Geography    2126
# Name: source_first_path_category_1st, dtype: int64

# %% [markdown]
# ##### Variable: source_dest_category_1st

# %% [markdown]
# Similarly, we get the statistic of category pairs. The category pairs contains the category of source articles and the category of destination articles.

# %%
click_category_count_depth1_source_dest = df_merge_finished_path_category['source_dest_category_1st'].value_counts(sort = True)
click_category_count_depth1_source_dest[0:10]
# Out:
# Science;Geography                  4600
# Geography;Geography                4520
# Science;Science                    4035
# Language_and_literature;Science    3617
# Science;History                    3492
# Geography;Science                  3342
# People;Geography                   2447
# Everyday_life;Science              2326
# Science;People                     2289
# Everyday_life;Geography            1960
# Name: source_dest_category_1st, dtype: int64

# %% [markdown]
# ##### Variable: path_pair

# %% [markdown]
# We analyse the variable **path pair**. The path pair with the highest frequency will be found. And in the later project, we will delve the reason why people tends to follow on those path pair.

# %%
df_path_pair_analysis = df_finished_path.copy(deep=True)
df_path_pair_analysis['path_pair'] = None

i = 0
path_pair_dict = {}
for index, row in df_finished_path['path'].items():
    string_path_pair = []
    string_array = row.split(";")
    for pair_index in range(len(string_array) - 4):
        if len(string_array) - 4:
            if string_array[pair_index] != '<' and string_array[pair_index+1] != '<':
                string_pair = '(' + string_array[pair_index] + ', ' + string_array[pair_index + 1] + ')'
                string_path_pair.append(string_pair)
                path_pair_dict[string_pair] = path_pair_dict.get(string_pair, 0) + 1
        df_path_pair_analysis['path_pair'][i] = string_path_pair
    i += 1

# %%
path_pair_dict_sort = dict(sorted(path_pair_dict.items(), key=operator.itemgetter(1), reverse=True))

# %%
print(list(path_pair_dict_sort.items())[:10])
# Out:
# [('(Brain, Computer_science)', 444), ('(Asteroid, Earth)', 267), ('(North_America, United_States)', 228), ('(Europe, United_Kingdom)', 223), ('(United_States, North_America)', 217), ('(England, Europe)', 213), ('(Pyramid, Mexico)', 169), ('(Computer_science, Internet)', 164), ('(Africa, Herbivore)', 160), ('(Batman, Scotland)', 158)]

# %%
plt.figure(figsize=(6, 18))
plt.barh(list(path_pair_dict_sort.keys())[80::-1], list(path_pair_dict_sort.values())[80::-1], color=mcolors.CSS4_COLORS, height=0.5)
plt.title('Frequency of pair path')
plt.xlabel('Number')
plt.ylabel('Path Pair')
# Out:
# Text(0, 0.5, 'Path Pair')

# %% [markdown]
# From the above results, we find that the path pair (Brain, Computer_science), (Asteroid, Earth), (North_America, United_States), (Europe, United_Kingdom) and (United_States, North_America) are the top 5 path pairs that occur. Most of these five path pairs include the information of geography and countries. It seems that this result strengthened our conclusion in the first part of this section: People tends to use the geographic location and nationality to find the target words.
# Then, take the path pair (North_America, United_States) for example. We would like to find in which source and target categories do people tend to generate this path pair. The outcome is as following:

# %%
df_temp = df_merge_finished_path_category[df_merge_finished_path_category['path_pair'].str.contains("(North_America, United_States)", regex=False)]

# %%
North_America_count_value = df_temp['source_dest_category_1st'].value_counts()

# %%
plt.figure(figsize=(6, 18))
ax = North_America_count_value[60::-1].plot.barh(x='Number', y='Geography Pair', color=mcolors.CSS4_COLORS)
plt.title('Frequency of source and target category')
plt.xlabel('Number')
plt.ylabel('Source and Target Category Pair')
# Out:
# Text(0, 0.5, 'Source and Target Category Pair')

# %% [markdown]
# From the result, we find that the path pair (North_America, United_States) always appear when the categories of the source and destination words are about science, geography and people. And people also click the United States in the North America article when the destination word belongs to IT and Technology. We consider that the selection of the article to click next is significantly impacted by the category of source and target words, however, when the category is not related to the path pair, people also click the article United States. It might could be explained by the contents that people scan during the game.
# In the later analysis, we will delve deeper into the influence of HTML page towards to the frequency of path pair. In more detail, we will discuss whether the HTML contents lead to the high occurrence frequency of path pair (North_America, United_States). Does the readability lead to the result above?

# %% [markdown]
# Then, we could continue to delve the source and destination articles. The specific detailed category of source and destination, which contains the path pair, is **subject.Science.Biology.General_Biology;subject.Design_and_Technology.Engineering**. So, later, we could find the specific articles to find the reason why people think the path pair (Brain, Computer_science) could help their tasks.

# %%
df_temp['source_dest_category'].value_counts()[:10]
# Out:
# subject.Science.Biology.Mammals;subject.Geography.North_American_Geography                          9
# subject.Countries;subject.Geography.North_American_Geography                                        8
# subject.Science.Biology.Birds;subject.People.USA_Presidents                                         8
# subject.Science.Biology.Insects_Reptiles_and_Fish;subject.Citizenship.Law                           7
# subject.Science.Biology.Birds;subject.Science.Physics.Space_transport                               7
# subject.Science.Biology.Plants;subject.People.Performers_and_composers                              6
# subject.Geography.Geology_and_geophysics;subject.Geography.North_American_Geography                 6
# subject.Science.Biology.General_Biology;subject.Design_and_Technology.Engineering                   6
# subject.Geography.Geography_of_Great_Britain;subject.People.USA_Presidents                          6
# ...

# %% [markdown]
# ## LDA topic modeling
# We use Latent Dirichlet Allocation (LDA) as topic model to extract topics of the plain text dataset, and more importantly obtain the topis distribution within each article. With topic distribution information, we can clearly see the changes in topic within the clicking path. Most intuitively, people may try to find the relation between the two articles and the article topic would become closer and closer to the target article’s topic as the click process goes on. For example when navigating from ‘Zebra’ to ‘French Revolution’, the elements of animals may decrease and the elements of history or politics may increase through the path.

# %% [markdown]
# ### Introduction

# %% [markdown]
# In natural language processing, Latent Dirichlet Allocation (LDA) is a generative statistical model that explains a set of observations through unobserved groups, and each group explains why some parts of the data are similar.

# %% [markdown]
# ### Mathematics Explanation:

# %% [markdown]
# The model is as following:

# %%
Image(filename = './LDA_mathematic.jpg', width=1000, height=800)

# %% [markdown]
# According to the model, the total probability of the model is:
#
# If the document collection is sufficiently large, LDA will discover such sets of terms (i.e., topics) based upon the co-occurrence of individual terms, though the task of assigning a meaningful label to an individual topic (i.e., that all the terms are DOG_related) is up to the user, and often requires specialized knowledge (e.g., for collection of technical documents). The LDA approach assumes that:
#
# The semantic content of a document is composed by combining one or more terms from one or more topics.
# Certain terms are ambiguous, belonging to more than one topic, with different probability. (For example, the term training can apply to both dogs and cats, but are more likely to refer to dogs, which are used as work animals or participate in obedience or skill competitions.) However, in a document, the accompanying presence of specific neighboring terms (which belong to only one topic) will disambiguate their usage.
# Most documents will contain only a relatively small number of topics. In the collection, e.g., individual topics will occur with differing frequencies. That is, they have a probability distribution, so that a given document is more likely to contain some topics than others.
# Within a topic, certain terms will be used much more frequently than others. In other words, the terms within a topic will also have their own probability distribution.
# When LDA machine learning is employed, both sets of probabilities are computed during the training phase, using Bayesian methods and an Expectation Maximization algorithm.

# %% [markdown]
# ### LDA text preprocess
# Our LDA model is generated from the 'plaintext_articles' dataset. Necessary functions are listed below.

# %%
def load_plaintext():
    """
    Load txt files from 'plaintext_articles' folder with alphabetical order.
    Delete copyright and source info.
    """
    path = 'plaintext_articles'
    files = os.listdir(path)
    files.sort(key=lambda x:str(x.split('.')[0]).lower())
    texts = []
    for i, file in enumerate(files):
        if os.path.splitext(file)[1] == '.txt':
            file_path = os.path.join(path, file)
            with open(file_path, "r", encoding='utf-8') as f:
                txt = [line.strip() for line in f.readlines()]
                del txt[-5:-1]  #retrieved info
                del txt[0]      #copyright line
                try:
                    texts.append(txt)
                except Exception as e:
                    print(e)
    print("Finish loading plaintext.")
    return texts


def sent_to_words(sentences):
    """
    For each article, split words from sentences and remove digits.
    """
    for sentence in sentences:
        # deacc=True removes punctuations
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))
    print("Finish transforming sentences to words.")

    
def clean_digit_short(texts):
    """
    Remove numbers and one character words
    """
    texts = [[token for token in doc if not token.isdigit()] for doc in texts]
    texts = [[token for token in doc if len(token) > 3] for doc in texts]
    print("Finish cleaning digits and short words.")
    return texts


def form_bigrams(texts):
    """
    Form bigrams with at least 5 counts.
    """
    bigram = gensim.models.Phrases(texts, min_count=5, threshold=100.0)
    print("Finish creating bigrams.")
    return [bigram[doc] for doc in texts], bigram


def remove_stopwords(texts):
    """
    Remove stopwords.
    """
    stopwords = nlp.Defaults.stop_words
    stopwords |= {'january', 'february', 'april', 'may', 'june', 'july', 'august', 'september',\
                  'october', 'november', 'december', 'monday', 'tuesday', 'wednesday', 'thursday',\
                  'friday', 'saturday', 'sunday'}
    print("Finish removing stop words.")    
    return [[word for word in simple_preprocess(str(doc)) 
             if word not in stopwords] for doc in texts]


def lemmatization(texts, allowed_postags=['NOUN']):
    """
    Do lemmatization and only keep nouns.
    """
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    print("Finish lemmatization.")
    return texts_out


def lda_preprocess():
    """
    Call data preparation functions.
    Create dictionary and corpus.
    """
    data = load_plaintext()
    data_words = list(sent_to_words(data))
    data_words = clean_digit_short(data_words)
    data_words = remove_stopwords(data_words)
    data_words = form_bigrams(data_words)[0]
    data_words = lemmatization(data_words, allowed_postags=['NOUN'])

    id2word = corpora.Dictionary(data_words)
    id2word.filter_extremes(no_below=5, no_above=0.5)

    corpus = [id2word.doc2bow(text) for text in data_words]
    return data_words, id2word, corpus

# %% [markdown]
# To determain the best number of topic in LDA model, we use 2 metrics: coherence score (c_v) and self-defined function: topic diversity, which gives us the proportion of unique words. <br>
# We can first find an approximate interval where the best number of topics lies, then do fine-tuning.

# %%
def topic_diversity(lda_model, t):
    """
    Calculate topic diversity score.
    Score = proportion of unique words
    """
    topics = str(lda_model.print_topics(t))
    topics = re.sub(r'\W|1|2|3|4|5|6|7|8|9', "", topics)
    topics = re.sub(r'0', " ", topics)
    topiclist = topics.split(' ')
    topiclist = [x for x in topiclist if x != '']
    topicset = set(topiclist)
    diversity_score = len(topicset)/len(topiclist)
    return diversity_score

# %%
def lda_param_tune():
    num_topics = [5, 10, 15, 20, 25]
    lda_models = []
    for n in num_topics:
        lda_model = gensim.models.LdaModel(corpus=corpus,
                                    id2word=id2word,
                                    num_topics=n, 
                                    random_state=42,
                                    passes = 10)
        lda_models.append(lda_model)
        coherence_model_lda = CoherenceModel(model=lda_model, texts=data_words, \
                          dictionary=id2word, coherence='c_v')
        coherence_score = coherence_model_lda.get_coherence()
        diversity_score = topic_diversity(lda_model, n)
        comprehensive_score = float(coherence_score) * float(diversity_score)
        print("number of topics", n, "coherence_score :", '%.4f'%coherence_score, "diversity_score: ", '%.4f'%diversity_score,
             "comprehensive score :", '%.4f'%comprehensive_score)

        
def lda_param_finetune(start, end):
    lda_models = []
    for n in range(start, end):
        lda_model = gensim.models.LdaModel(corpus=corpus,
                                    id2word=id2word,
                                    num_topics=n, 
                                    random_state=42,
                                    passes = 10)
        lda_models.append(lda_model)
        coherence_model_lda = CoherenceModel(model=lda_model, texts=data_words, \
                          dictionary=id2word, coherence='c_v')
        coherence_score = coherence_model_lda.get_coherence()
        diversity_score = topic_diversity(lda_model, n)
        comprehensive_score = float(coherence_score) * float(diversity_score)
        print("number of topics", n, "coherence_score :", '%.4f'%coherence_score, "diversity_score: ", '%.4f'%diversity_score,
             "comprehensive score :", '%.4f'%comprehensive_score)
    return lda_models

# %%
data_words, id2word, corpus = lda_preprocess()
# Out:
# Finish loading plaintext.
# Finish transforming sentences to words.
# Finish cleaning digits and short words.
# Finish removing stop words.
# Finish creating bigrams.
# Finish lemmatization.

# %%
lda_param_tune()
# Out:
# number of topics 5 coherence_score : 0.4671 diversity_score:  0.9400 comprehensive score : 0.4391
# number of topics 10 coherence_score : 0.5456 diversity_score:  0.9400 comprehensive score : 0.5129
# number of topics 15 coherence_score : 0.5713 diversity_score:  0.8933 comprehensive score : 0.5103
# number of topics 20 coherence_score : 0.6017 diversity_score:  0.8600 comprehensive score : 0.5175
# number of topics 25 coherence_score : 0.5941 diversity_score:  0.8240 comprehensive score : 0.4895
# ...

# %% [markdown]
# Consider both coherence and diversity score, the approximate interval is between 10 and 20. We can do fine tune now to get the best topic number.

# %%
lda_param_finetune(10, 20)
# Out:
# number of topics 10 coherence_score : 0.5456 diversity_score:  0.9400 comprehensive score : 0.5129
# number of topics 11 coherence_score : 0.5428 diversity_score:  0.8545 comprehensive score : 0.4638
# number of topics 12 coherence_score : 0.5704 diversity_score:  0.8750 comprehensive score : 0.4991
# number of topics 13 coherence_score : 0.5691 diversity_score:  0.8923 comprehensive score : 0.5078
# number of topics 14 coherence_score : 0.5727 diversity_score:  0.9071 comprehensive score : 0.5195
# number of topics 15 coherence_score : 0.5713 diversity_score:  0.8933 comprehensive score : 0.5103
# number of topics 16 coherence_score : 0.6012 diversity_score:  0.9062 comprehensive score : 0.5448
# number of topics 17 coherence_score : 0.5985 diversity_score:  0.9000 comprehensive score : 0.5387
# number of topics 18 coherence_score : 0.6006 diversity_score:  0.8444 comprehensive score : 0.5071
# ...

# %% [markdown]
# Now we get our best parameter: there are 16 topics in our dataset. We can see top words in the final LDA model and also visualize the LDA model.

# %%
lda_model = gensim.models.LdaModel(corpus=corpus,
                                    id2word=id2word,
                                    num_topics=16, 
                                    random_state=42,
                                    passes = 10)

# %% [markdown]
# We can manually give each topic a name.

# %%
topics = ['Music', 'Space and Cosmos', 'Sports', 'Urban Construction', 'Literature', 'Movie',
         'Social Study', 'Electronics Industry', 'Health', 'Information Technology', 'Chemical Processes',
         'Government Affairs', 'Religion', 'Military', 'Political Campaign', 'Nature']

# %% [markdown]
# <table>
#   <thead>
#     <tr>
#       <th>Topic</th>
#       <th>Topic Words</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Music</td>
#       <td>music, song, band, album, record, style, tour, instrument, sound, opera</td>
#     </tr>
#     <tr>
#       <td>Space and Cosmos</td>
#       <td>earth, system, planet, energy, space, temperature, surface, star, point, distance</td>
#     </tr>
# 	<tr>
#       <td>Sports</td>
#       <td>player, team, game, ball, flight, event, sport, season, engine, championship</td>
#     </tr>
# 	<tr>
#       <td>Urban Construction</td>
#       <td>city, building, line, town, station, school, park, centre, service, university</td>
#     </tr>
# 	<tr>
#       <td>Literature</td>
#       <td>work, book, artist, painting, poet, poem, pound, line, novel, style"'</td>
#     </tr>
# 	<tr>
#       <td>Movie</td>
#       <td>film, character, story, series, episode, book, theatre, role, movie, production</td>
#     </tr>
# 	<tr>
#       <td>Social Study</td>
#       <td>theory, society, work, study, idea, science, philosophy, example, research, school</td>
#     </tr>
# 	<tr>
#       <td>Electronics Industry</td>
#       <td>company, network, system, television, radio, information, article, internet, telephone, video</td>
#     </tr>
# 	<tr>
#       <td>Health</td>
#       <td>disease, cell, vitamin, blood, treatment, body, patient, virus, study, child</td>
#     </tr>
# 	<tr>
#       <td>Information Technology</td>
#       <td>system, game, window, computer, version, user, program, software, server, application</td>
#     </tr>
# 	<tr>
#       <td>Chemical Processes</td>
#       <td>water, metal, material, process, plant, production, wine, element, product, method</td>
#     </tr>
# 	<tr>
#       <td>Government Affairs</td>
#       <td>country, government, flag, population, island, region, nation, economy, language, territory</td>
#     </tr>
# 	<tr>
#       <td>Religion</td>
#       <td>king, language, church, word, death, period, empire, emperor, tradition, city</td>
#     </tr>
# 	<tr>
#       <td>Military</td>
#       <td>force, army, battle, storm, ship, troop, attack, damage, soldier, wind</td>
#     </tr>
# 	<tr>
#       <td>Political Campaign</td>
#       <td>government, member, power, party, election, leader, office, parliament, vote, policy</td>
#     </tr>
# 	<tr>
#       <td>Nature</td>
#       <td>specie, water, animal, bird, river, tree, family, plant, fish, tooth</td>
#     </tr>
#   </tbody>
# </table>

# %%
model_data = pyLDAvis.gensim_models.prepare(lda_model, corpus, id2word)
pyLDAvis.display(model_data)

# %% [markdown]
# We also create a visualization plot of our LDA model. The code is store in the file **/src/lda_page.html**. It is an interactive plot.

# %%
Image(filename = './Ida_page.png', width=1000, height=800)

# %% [markdown]
# We store the topic distribution into a dataframe.

# %%
# Load plain text
df_plaintext = pd.DataFrame()
path = os.path.join(PATH_DATASET, 'plaintext_articles')
files = os.listdir(path)
files.sort(key=lambda x:str(x.split('.')[0]).lower())
texts = []
articles = []
for i, file in enumerate(files):
    if os.path.splitext(file)[1] == '.txt':
        file_path = os.path.join(path, file)
        with open(file_path, "r", encoding='utf-8') as f:
            txt = [line.strip() for line in f.readlines()]
            article = txt[2]
            del txt[-5:-1]  #retrieved info
            del txt[0:2]      #copyright line
            try:
                texts.append(txt)
                articles.append(article)
            except Exception as e:
                print(e)
df_plaintext['article'] = articles
df_plaintext['plaintext'] = texts

# %%
df = pd.DataFrame()
df['topics'] = lda_model.get_document_topics(corpus)
sf = pd.DataFrame(data=df['topics'])
df_lda_topic = pd.DataFrame()
for i in range(len(topics)):
    df_lda_topic[str(i)]=[]
frames = [sf,df_lda_topic]
df_lda_topic = pd.concat(frames).fillna(0)
for i in range(4604):
    for j in range(len(df['topics'][i])):
        df_lda_topic[str(df['topics'][i][j][0])].loc[i] = df['topics'][i][j][1]
df_lda_topic.drop('topics', axis=1, inplace=True)
df_lda_topic.columns = topics
df_lda_topic = df_lda_topic.set_index(df_plaintext['article'])
del df, sf, frames

# %% [markdown]
# To give you an idea of how this works in practice, let’s consider the example of Édouard Manet, the famous French painter. In Wikispeedia, Manet would be classified under the category of "People.Artists". However, this classification tells us very little about the specific content of Manet's page or the themes and topics that it covers.
#
# Our LDA model allowed us to delve into the actual content of Manet's page, where the most significant topic was "Art and literature." This suggests that Manet's page is heavily focused on topics related to the world of art and literature, such as his paintings, artistic style, and the cultural context in which he worked.

# %%
monet = df_lda_topic.iloc[2]
monet.plot(kind='bar', stacked=True,alpha=1, colormap=plt.cm.RdYlBu, legend=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can then analyze the topic change through articles. We select and analyze those paths that appeared at least five times with the same source and destination.

# %%
def get_pathnum(group):
    return group['pathnum'].tolist()

lda_grouped = df_finished_path_rm_outlier.groupby(['source', 'destination']).filter(lambda x: len(x) > 4)
lda_grouped = lda_grouped.groupby(['source', 'destination'])
pathnums = lda_grouped.apply(get_pathnum)

# %%
def topic_change_vis_single(num):
    """
    Given a list of articles, visualize the changes in topic.
    """
    tdf = df_lda_topic.iloc[num]
    tdf.reset_index(drop=True, inplace=True)
    tdf.plot(kind='area', alpha=1, colormap=plt.cm.RdYlBu).legend(loc='center left',bbox_to_anchor=(1.0, 0.5))

def topic_change_vis(paths):
    """
    Given several lists of articles, visualize the changes in topic into one image.
    """
    n = len(paths)
    alpha = 1/n
    ax = None
    length = max(len(path) for path in paths)
    for path in paths:
        tdf = df_lda_topic.iloc[path]
        tdf.reset_index(drop=True, inplace=True)
        if ax is None:
            ax = tdf.plot(kind='area', alpha=alpha, colormap=plt.cm.RdYlBu, legend=False)
        else:
            tdf.plot(kind='area', alpha=alpha, colormap=plt.cm.RdYlBu, ax=ax, legend=False)
    plt.show()

# %% [markdown]
# We can then analyze the topic change through articles.
#
# For instance, one user who was assigned the path from "People's Republic of China" to "Jesus" took the following route: "People's Republic of China" - "Giant's Causeway" - "Martin Luther King, Jr." - "Last Supper" - "Jesus." This path showed a clear trend of the proportion of religion-related topics increasing as the user progressed towards the destination. (First figure below)
#
# Another user with the same start and destination took a different path: "People's Republic of China" - "Latin" - "Romulus Augustus" - "Christmas Island" - "Jesus." While this path also showed a similar trend of increasing religion-related topics, it took the user several more steps to reach the final destination. (Second figure below)
#
# It seems that we often see that the transition between the topics of "government affairs" and "religion" goes through intermediate topics such as "nature" or "urban construction." However, this can vary significantly between different users. (Last figure below)

# %%
path1 = pathnums[771][1]
# "People's Republic of China" - "Giant's Causeway" - "Martin Luther King, Jr." - "Last Supper" - "Jesus"
topic_change_vis_single(path1)

path2 = pathnums[771][5]
# 14th_century;Niger;Nigeria;British_Empire;Slavery;Africa;Atlantic_slave_trade;African_slave_trade
topic_change_vis_single(path2)

PRCtoJesus = pathnums[771][3:-1]
topic_change_vis(PRCtoJesus)

# %% [markdown]
# From the above analysis, we draw to the conclusion that thought we might expect the distribution of topics within the links that users click on to follow a linear or summable path, this is not always the case in practice. Instead, the overall trend of topic distribution within the paths that users choose tends to evolve towards the target, but due to differences in prior knowledge and the unknown nature of the chosen links, it is difficult to develop a comprehensive method for fully capturing the users' thought processes.

# %% [markdown]
# ## Readability Analysis
#
# In this part, we will delve into the reason why people always choose those high-frequency links discussed in the first section. We will mainly research on: is there a relationship between the links that people choose and the readability of the sentences that contain those links? Do people always choose those links which is easy to understand? <br>

# %% [markdown]
# ### Mathematical Equations
#
# We will introduce several methods to realize the readability calculation <br>
#
# We will first load all articles and use them to show the process of readability calculation.

# %%
# load txt files from folder, delete copyright and source info, save each article as a str
def load_article_str():
    fname = os.path.join(PATH_DATASET, 'wikispeedia_articles_plaintext/plaintext_articles')
    files = os.listdir(fname)
    data_str = []
    for i, file in enumerate(files):
        if os.path.splitext(file)[1] == '.txt':
            file_path = os.path.join(fname, file)
            with open(file_path, "r", encoding='utf-8') as f:
                txt = [line.strip() for line in f.readlines()]
                del txt[-5:-1]  #retrieved info
                del txt[0]      #copyright line
                txt_str = ' '.join(str(e) for e in txt)
                try:
                    data_str.append(txt_str)
                except Exception as e:
                    print(e)
    print("Finish loading data.")
    return data_str

data_str = load_article_str()
# Out:
# Finish loading data.

# %% [markdown]
# Here we use the first article in our dataset to test different readability metrics.

# %% [markdown]
# The readability evaluation methods we use are as following:
# 1.	Flesch reading-ease
# 2.	Flesch-Kincaid Grade Level
# 3.	Dale Chall Readability
# 4.	Automated Readability Index (ARI)
# 5.	Coleman Liau Index
# 6.	Gunning Fog

# %%
text = data_str[0]
r = Readability(text)

# %% [markdown]
# #### Flesch reading-ease
# 90-100 : Very Easy</br>
# 80-89 : Easy</br>
# 70-79 : Fairly Easy</br>
# 60-69 : Standard</br>
# 50-59 : Fairly Difficult</br>
# 30-49 : Difficult</br>
# 0-29 : Very Confusing</br>
# • Scores between 90.0 and 100.0 are considered easily understandable by an average 5th grader.</br>
# • Scores between 60.0 and 70.0 are considered easily understood by 8th and 9th graders.</br>
# • Scores between 0.0 and 30.0 are considered easily understood by college graduates</br></br>
# The specific mathematical formula is:</br>
# RE = 206.835 – (1.015 x ASL) – (84.6 x ASW)</br>
# RE = Readability Ease</br>
# ASL = Average Sentence Length (i.e., the number of words divided by the number of sentences)</br>
# ASW = Average number of syllables per word (i.e., the number of syllables divided by the number of words)

# %%
score_list = []
f = r.flesch()
print("The Flesch reading-ease Score is: ")
print(f.score)
print(f.ease)
print(f.grade_levels)
score_list.append(f.score)
# Out:
# The Flesch reading-ease Score is:
# 58.09490073209676
# fairly_difficult
# ['10', '11', '12']

# %% [markdown]
# #### Flesch-Kincaid Grade Level
# Round the score and get the grade level </br></br>
# The specific mathematical formula is:</br>
# FKRA = (0.39 x ASL) + (11.8 x ASW) - 15.59</br>
# Where,</br>
# FKRA = Flesch-Kincaid Reading Age</br>
# ASL = Average Sentence Length (i.e., the number of words divided by the number of sentences)</br>
# ASW = Average number of Syllable per Word (i.e., the number of syllables divided by the number of words)

# %%
fk = r.flesch_kincaid()
print("The Flesch-Kincaid Grade Level Score is: ")
print(fk.score)
print(fk.grade_level)
score_list.append(fk.score)
# Out:
# The Flesch-Kincaid Grade Level Score is:
# 10.619742987318112
# 11

# %% [markdown]
# #### Dale Chall Readability
# Dale Chall Readability is based on the use of familiar words, rather than syllable or letter counts. Reading tests show that readers usually find it easier to read, process and recall a passage if they find the words familiar.</br></br>
# The formula for calculating the raw score of the Dale–Chall readability score is given below:</br>
# Raw Score = 0.1579 * (PDW) + 0.0496 * ASL</br>
# Raw Score = Reading Grade of a reader who can comprehend your text at 3rd grade or below.</br>
# PDW = Percentage of Difficult Words</br>
# ASL = Average Sentence Length in words</br>
# If (PDW) is greater than 5%, then:</br>
# Adjusted Score = Raw Score + 3.6365, otherwise Adjusted Score = Raw Score</br>
# Adjusted Score = Reading Grade of a reader who can comprehend your text at 4th grade or above.

# %%
dc = r.dale_chall()
print("The Dale Chall Readability Score is: ")
print(dc.score)
print(dc.grade_levels)
score_list.append(dc.score)
# Out:
# The Dale Chall Readability Score is:
# 10.579819445994886
# ['college_graduate']

# %% [markdown]
# #### Automated Readability Index (ARI)
# Unlike the other indices, the ARI, along with the Coleman-Liau, relies on a factor of characters per word, instead of the usual syllables per word. ARI is widely used on all types of texts.
# 5-6 yrs. old — Kindergarten</br>
# 6-7 yrs. old — 1st Grade</br>
# 7-8 yrs. old — 2nd Grade</br>
# 8-9 yrs. old — 3rd Grade</br>
# 9-10 yrs. old — 4th Grade</br>
# 10-11 yrs. old — 5th Grade</br>
# 11-12 yrs. old — 6th Grade</br>
# 12-13 yrs. old — 7th Grade</br>
# 13-14 yrs. old — 8th Grade</br>
# 14-15 yrs. old — 9th Grade</br>
# 15-16 yrs. old — 10th Grade</br>
# 16-17 yrs. old — 11th grade</br>
# 17-18 yrs. old — 12th grade</br>
# 18-22 yrs. old - College</br></br>
# Here is the formula to calculate the Automated Readability Index:</br>
# ARI = 4.71(characters/words)+0.5(words/sentences)-21.43

# %%
ari = r.ari()
print("The Automated Readability Index (ARI) Score is: ")
print(ari.score)
print(ari.grade_levels)
print(ari.ages)
score_list.append(ari.score)
# Out:
# The Automated Readability Index (ARI) Score is:
# 11.905379872532095
# ['12']
# [17, 18]

# %% [markdown]
# #### Coleman Liau Index
# The Coleman-Liau Formula usually gives a lower grade value than any of the Kincaid, ARI and Flesch values when applied to technical documents.</br></br>
# Calculate the Coleman–Liau Index with the following formula:</br>
# CLI = 0.0588L - 0.296S -15.8</br>
# where</br>
# L is the average number of letters per 100 words. </br>
# S is the average number of sentences per 100 words.

# %%
cl = r.coleman_liau()
print("The Coleman Liau Index Score is: ")
print(cl.score)
print(cl.grade_level)
score_list.append(cl.score)
# Out:
# The Coleman Liau Index Score is:
# 10.220989888238424
# 10

# %% [markdown]
# #### Gunning Fog
# The Gunning fog index measures the readability of English writing. The index estimates the years of formal education needed to understand the text on a first reading. A fog index of 12 requires the reading level of a U.S. high school senior (around 18 years old).</br></br>
# The mathematical formula is:</br>
# Grade Level = 0.4 (ASL + PHW)</br>
# where,</br>
# ASL = Average Sentence Length (i.e., number of words divided by the number of sentences)</br>
# PHW = Percentage of Hard Words

# %%
gf = r.gunning_fog()
print("The Gunning Fog Score is: ")
print(gf.score)
print(gf.grade_level)
score_list.append(gf.score)
# Out:
# The Gunning Fog Score is:
# 11.762979789457289
# 12

# %% [markdown]
# From the above examples, we find that all those readability calculation metrics give us similar results towards the plaintexts in the dataset. We will use the evaluation matrix Flesch reading-ease Score in our analysis later.

# %% [markdown]
# We use the plaintext in our dataset as example to test those six evaluation approaches, the readability score for these six methods is shown in the following diagram:

# %%
# plot the results
xlabel = ['Flesch reading-ease', 'Flesch-Kincaid Grade Level', 'Dale Chall Readability',
          'Automated Readability Index (ARI)', 'Coleman Liau Index', 'Gunning Fog']
plt.bar(xlabel, score_list)
plt.xticks(rotation=45)
plt.ylabel("Readability Score")
plt.xlabel("Evaluation Metrics")
plt.grid(drawstyle="steps")
plt.title("Score of Different Readability Matrics")
# Out:
# Text(0.5, 1.0, 'Score of Different Readability Matrics')

# %% [markdown]
# From the above results, we find that the score of Flesch reading-ease is different from the other scores. The reason is that it uses a distinct scoring formula comparing with others. If we check the converted grade level from the score, the grade levels are almost the same. Therefore, in the later analysis, we will only use the Flesch reading-ease to calculate the readability of contents in the webpage. In the Flesch reading-ease, a higher score means it is easier for human to understand.

# %% [markdown]
# ### Analysis the Readability of the Link that People Choose

# %% [markdown]
# #### What is the readability of sentences which include the high frequency path pair?
#
# We continue to delve into the reason why several path pairs occur plenty of times in all games. In more detail, if the path pair is (Asteroid, Earth), we will calculate the readability score for all sentences including the link “Earth” in the article “Asteroid”. We choose the top5, top5-10, bottom 5-10 and bottom 5 path pair appearing in all finished path and calculate the readability of them. **For conciseness, we directly call this value the readability of the path pair**. The result is shown as:

# %%
def find_readability_pair(list_of_pairs):
    sentences = []
    for pair in list_of_pairs:
        pair = pair[1:-1] # delete "(" ")"
        words = pair.split(", ")
        if(words[0]=='<' or words[1]=='<'):
            continue
        article_1 = words[0]+".htm"
        article_2 = words[1]
        text = plain_txt_dict[article_1.replace('.htm','')]
        for article_count_list in page_link_dict.get(article_1):
            if(article_count_list[0]==article_2):
                temp_sent = find_sentence(text, article_count_list[0].replace('_',' '))
                if(len(temp_sent)!=0):
                    for sent in temp_sent:
                        sentences.append(sent)
                break
    print(len(sentences), "sentences sampled from those pairs")
    f_sentences = flatten_sentences_list(sentences)
    r = Readability(f_sentences)
    f = r.flesch()
    print("The sentences sampled from those pairs are", f.ease)
    print("The Flesch reading-ease Score is: ", f.score)
    print("It is suitable for", f.grade_levels)
    return f.score

# %% [markdown]
# In the first section of the notebook, we find that the highest clicking path pair are (for example, we generate the path pair accordign to the finished path, if the path is A->B->C, the path pair is (A, B), (B, C); we add up all those path pairs and calculate the readability of those articles in those path pairs):

# %% [markdown]
# Readability for top5 clicking article links

# %%
readability_list = []
print(list(path_pair_dict_sort.keys())[:5])
list_of_pairs = list(path_pair_dict_sort.keys())[:5]
value1 = find_readability_pair(list_of_pairs)
readability_list.append(value1)
# Out:
# ['(Brain, Computer_science)', '(Asteroid, Earth)', '(North_America, United_States)', '(Europe, United_Kingdom)', '(United_States, North_America)']
# 44 sentences sampled from those pairs
# The sentences sampled from those pairs are very_confusing
# The Flesch reading-ease Score is:  10.544052433510274
# It is suitable for ['college_graduate']

# %% [markdown]
# Readability for top5-10 clicking article links

# %%
print(list(path_pair_dict_sort.keys())[5:10])
list_of_pairs = list(path_pair_dict_sort.keys())[:5]
value1 = find_readability_pair(list_of_pairs)
readability_list.append(value1)
# Out:
# ['(England, Europe)', '(Pyramid, Mexico)', '(Computer_science, Internet)', '(Africa, Herbivore)', '(Batman, Scotland)']
# 44 sentences sampled from those pairs
# The sentences sampled from those pairs are very_confusing
# The Flesch reading-ease Score is:  10.544052433510274
# It is suitable for ['college_graduate']

# %% [markdown]
# Readability for bottom 5-10 clicking article links

# %%
print(list(path_pair_dict_sort.keys())[-10:-5])
list_of_pairs = list(path_pair_dict_sort.keys())[-5:-1]
value1 = find_readability_pair(list_of_pairs)
readability_list.append(value1)
# Out:
# ['(War_in_Somalia_%282006%E2%80%93present%29, Ethiopia)', '(William_Thomson%2C_1st_Baron_Kelvin, Glasgow)', '(Human_rights, Communism)', '(Women%27s_rights, Property)', '(Work_%28thermodynamics%29, Energy)']
# 3 sentences sampled from those pairs
# The sentences sampled from those pairs are very_confusing
# The Flesch reading-ease Score is:  -2.625410122164027
# It is suitable for ['college_graduate']

# %% [markdown]
# Readability for bottom 1-5 clicking article links

# %%
print(list(path_pair_dict_sort.keys())[-5:])
list_of_pairs = list(path_pair_dict_sort.keys())[-5:-1]
value1 = find_readability_pair(list_of_pairs)
readability_list.append(value1)
# Out:
# ['(Work_%28thermodynamics%29, Cambridge)', '(Cambridge, City_status_in_the_United_Kingdom)', '(Yagan, Folklore)', '(19th_century, Charles_Dickens)', '(Yagan, Australia)']
# 3 sentences sampled from those pairs
# The sentences sampled from those pairs are very_confusing
# The Flesch reading-ease Score is:  -2.625410122164027
# It is suitable for ['college_graduate']

# %% [markdown]
# Draw the plot of above analysis

# %%
# plot the results
xlabel = ['(North_America, United_States) etc.', '(England, Europe) etc.', '(Work_%28thermodynamics%29, Energy) etc.',
          '(Yagan, Folklore) etc.']
range_list_min = []
range_list_max = []
plt.bar(xlabel, readability_list)
plt.xticks(rotation=45)
plt.ylabel("Flesch reading-ease Score")
plt.xlabel("Clicking Path Pair")
plt.grid(drawstyle="steps")
plt.title("Distribution of sentence readability to different path pair")
# Out:
# Text(0.5, 1.0, 'Distribution of sentence readability to different path pair')

# %% [markdown]
# From the above analysis, we find that the readability score of high frequency path pair is larger than the lower frequency path pair. It seems that people tend to click the link comes from a much easier understanding sentence which is same to our intuition. With this preliminary conclusion, we delve into the readability of all links appeared in the HTML pages.

# %% [markdown]
# #### What is the readability distribution over sentences which include different clicking frequency of links?

# %% [markdown]
# Again, for simplicity, we call the readability of sentences including a specific link as the readability of this link. In this part, we count on the frequency of all links that people could click in the webpages. And then we calculate the readability of those links from the corresponding plaintexts. Then, we will get a readability distribution over all links. We divide all links according to its clicking times into 10 intervals. Considering the larger amount of links and articles in the whole dataset, we carry out the readability calculation through sampling and repeat. In each procedure, we sample 5% articles and extract all links in them. Afterwards, we count the clicking number of those links and compute the readability value. The procedure has been repeated 10 times in total.

# %% [markdown]
# We will first obtain all links in the HTML page

# %%
# Read the article.tsv file
# read in the article names
article_path = '../dataset/wikispeedia_paths-and-graph/articles.tsv'

def read_txt_skip_line(path, skipline):
    article_list = []
    with open(path, 'r', encoding='utf-8') as f:
        for i in range(skipline):
            next(f)
        data = f.readlines()
        for li in data:
            article_list.append(li.strip('\n'))
    f.close()
    return article_list

article_list = read_txt_skip_line(article_path, 12)

# %% [markdown]
# Read all links in HTML pages and record them

# %%
# build a dictionary page_link_dict
# whose keys are article names
# values are corresponding links contained in those articles(as list)
HTML_folder_path = '../dataset/wikispeedia_articles_html/wpcd/wp'
page_link_dict = {}
for folder_name in os.listdir(HTML_folder_path):
    HTML_page_folder_path = os.path.join(HTML_folder_path, folder_name)
    if folder_name != 'index':
        for page_name in os.listdir(HTML_page_folder_path):
            if 'htm' in page_name:
                link_list = []
                page_path = os.path.join(HTML_page_folder_path, page_name)
                with open(page_path, 'r', encoding='ISO-8859-1') as f:
                    bsObj = BeautifulSoup(f.read(), 'html.parser')
                    # Find all links with <a> and href attribute
                    t1 = bsObj.find_all(name='a',attrs={"href":re.compile(r'^((?!png|jpg).)*.htm*((?!png|jpg).)*$')})
                    for link in t1:
                        if 'href' in link.attrs.keys() and 'title' in link.attrs.keys():
                            temp_str = urllib.parse.unquote(link['href'])
                            htm_index = temp_str.rfind('.htm')
                            line_index = len(temp_str)
                            while(True):
                                line_index = temp_str[:line_index].rfind('/')
                                if line_index <= htm_index:
                                    break
                            link_name = temp_str[line_index+1:htm_index]
                            if link_name in article_list and link_name not in link_list:
                                link_list.append(link_name)
                    # Find all links with <link> and href attribute
                    t2 = bsObj.find_all(name='link',attrs={"href":re.compile(r'^((?!png|jpg).)*.htm*((?!png|jpg).)*$')})
                    for link in t2:
                        if 'href' in link.attrs.keys():
                            temp_str = urllib.parse.unquote(link['href'])
                            htm_index = temp_str.rfind('.htm')
                            line_index = len(temp_str)
                            while(True):
                                line_index = temp_str[:line_index].rfind('/')
                                if line_index <= htm_index:
                                    break
                            link_name = temp_str[line_index+1:htm_index]

                            if link_name in article_list and link_name not in link_list:
                                link_list.append(link_name)
                page_link_dict[page_name] = link_list

# %%
# For values in the dictionary, initialize a zero
# this number will indicate
# in article key, how many times the users click link value[i]
for key in page_link_dict:
    list_occur = []
    for article in page_link_dict.get(key):
        article = article.replace(' ', '_')
        list_temp = [article,0]
        list_occur.append(list_temp)
    page_link_dict[key] = list_occur

# %%
# delete the last pair(head to destination) when analysis readability
df_finished_path_rm_outlier_read = df_finished_path_rm_outlier.copy(deep=True)
for index, row in df_finished_path_rm_outlier_read.iterrows():
    row['path_pair'].pop()

# %%
count_1 = 0
count_2 = 0
# iterate through all the pairs and calculate for each article
# how many times the links are clicked for each link
for index, row in df_finished_path_rm_outlier_read.iterrows():
    for pair in row['path_pair']:
        pair = pair[1:-1] # delete "(" ")"
        words = pair.split(", ")
        # if encounter backward, discard it for simplicity
        if(words[0]=='<' or words[1]=='<'):
            continue
        count_1 += 1
        article_1 = words[0]+".htm"
        article_2 = words[1]
        for idx, article_count_list in enumerate(page_link_dict.get(article_1)):
            if(article_count_list[0]==article_2):
                article_count_list[1] += 1
                count_2 +=1
                break
            if(idx == len(page_link_dict.get(article_1))-1):
                print("article_1", article_1)
                print("article_2", article_2)
                print("list: ", page_link_dict.get(article_1))
# check if every pair is proceeded and add number to the dictionary
print("Total number of pairs in dataframe: ", count_1)
print("Number of pairs proceeded: ", count_2)
print("Number of pairs proceeded: ", count_2)
# Out:
# Total number of pairs in dataframe:  207872
# Number of pairs proceeded:  207872
# Number of pairs proceeded:  207872

# %%
# here's an example
# find the pair who has the maximum occurence
maxcount = 0
maxcount_art = None
source = None
for key in page_link_dict:
    for article_count_list in page_link_dict.get(key):
        if(article_count_list[1]>maxcount):
            maxcount = article_count_list[1]
            maxcount_art = article_count_list[0]
            source = key
print(maxcount)
print(maxcount_art)
print(source)
# Out:
# 484
# United_States
# North_America.htm

# %%
# load plain txt files from folder, delete copyright and source info
# save them to a dictionary
# whose keys are article names, values are corresponding text
def load_plain_txt():
    fname = os.path.join(PATH_DATASET, 'wikispeedia_articles_plaintext')
    fname = os.path.join(fname, 'plaintext_articles')
    files = os.listdir(fname)
    plain_txt_dict = {}
    for i, file in enumerate(files):
        if os.path.splitext(file)[1] == '.txt':
            name = os.path.splitext(file)[0]
            file_path = os.path.join(fname, file)
            with open(file_path, "r", encoding='utf-8') as f:
                txt = [line.strip() for line in f.readlines()]
                del txt[-5:-1]  #retrieved info
                del txt[0]      #copyright line
                txt_str = ' '.join(str(e) for e in txt)
                try:
                    plain_txt_dict[name]=txt_str
                except Exception as e:
                    print(e)
    print("Finish loading plain txt to a dict.")
    return plain_txt_dict

plain_txt_dict = load_plain_txt()
# Out:
# Finish loading plain txt to a dict.

# %%
# find all the sentences that contains specific word within a given article
def find_sentence(article, word):
    """
    article: input article with type str
    word: input word going to be find with type str

    sentences: output sentences in the article that contains word
    """
    sentences = re.findall(r"([^.]*?"+word+"[^.]*\.)",article)
    #flat_sentences = [item for sublist in sentences for item in sublist]
    return sentences

# flatten n number of sentences to dim 1
def flatten_sentences_list(sentences):
    sentences_str = ''
    for sentence in sentences:
        sentences_str += sentence
    return sentences_str

# %%
# define a readability calculation function
def calculate_readability(sample_rate):
    """
    Input:
        sample_rate: the proportion that is going to be sampled of all articles
    What it does:
        for every article sampled, for every link in it
        first find the maximum number of link click
        then use 95% and 5% as threshold to find the most clicked links and least clicked links
        get their sentences and calculate the readability
    Output:
        f_score_most: the Flesch reading-ease Score of most clicked links sentences
        f_score_least: the Flesch reading-ease Score of least clicked links sentences
    """
    # sample articles
    sampled_art = []
    for key in page_link_dict:
        random_number = random.uniform(0, 1)
        if(random_number < sample_rate and plain_txt_dict.get(key.replace('.htm',''))!=None):
            sampled_art.append(key)

    other_sentences = []
    clicked_most_sentences = []
    for art in sampled_art:
        text = plain_txt_dict[art.replace('.htm','')]
        max_count = 0

        judge = 0
        for article_count_list in page_link_dict.get(art):
            if(article_count_list[1]>1):
                judge = 1
        if(judge==0):
            continue
        # find the maximum click number and calculate thresholds
        for article_count_list in page_link_dict.get(art):
            if(article_count_list[1]>max_count):
                max_count = article_count_list[1]
        threshold_up = 0.95 * max_count
        threshold_down = 0.05 * max_count
        # find sentences according to thresholds
        for article_count_list in page_link_dict.get(art):
            if(article_count_list[1]>threshold_up):
                temp_sent = find_sentence(text, article_count_list[0].replace('_',' '))
                if(len(temp_sent)!=0):
                    for sent in temp_sent:
                        clicked_most_sentences.append(sent)
            if(article_count_list[1]<threshold_down):
                temp_sent = find_sentence(text, article_count_list[0].replace('_',' '))
                if(len(temp_sent)!=0):
                    for sent in temp_sent:
                        other_sentences.append(sent)
    # print how many sentences are sampled and calculate readability
    print(len(clicked_most_sentences), "sentences sampled from top clicked links.")
    print(len(other_sentences), "sentences sampled from least clicked links.")
    f_clicked_most_sentences = flatten_sentences_list(clicked_most_sentences)
    f_other_sentences = flatten_sentences_list(other_sentences)
    r = Readability(f_clicked_most_sentences)
    f = r.flesch()
    print("The sentences sampled from top clicked links are", f.ease)
    print("The Flesch reading-ease Score is: ", f.score)
    print("It is suitable for", f.grade_levels)
    f_score_most = f.score
    r = Readability(f_other_sentences)
    f = r.flesch()
    print("The sentences sampled from least clicked links are", f.ease)
    print("The Flesch reading-ease Score is: ", f.score)
    f_score_least = f.score
    return f_score_most, f_score_least

# %%
# sample five times each 5%
f_most_scores = []
f_least_scores = []
for i in range(10):
    f_score_most, f_score_least = calculate_readability(sample_rate=0.05)
    f_most_scores.append(f_score_most)
    f_least_scores.append(f_score_least)
    print("-"*10)
# Out:
# 1284 sentences sampled from top clicked links.
# 5918 sentences sampled from least clicked links.
# The sentences sampled from top clicked links are very_confusing
# The Flesch reading-ease Score is:  25.5302699740991
# It is suitable for ['college_graduate']
# The sentences sampled from least clicked links are very_confusing
# The Flesch reading-ease Score is:  -8.755944011046495
# ----------
# 872 sentences sampled from top clicked links.
# 4408 sentences sampled from least clicked links.
# The sentences sampled from top clicked links are very_confusing
# The Flesch reading-ease Score is:  27.101739190852072
# It is suitable for ['college_graduate']
# The sentences sampled from least clicked links are very_confusing
# The Flesch reading-ease Score is:  3.8268169880936114
# ----------
# 997 sentences sampled from top clicked links.
# 4894 sentences sampled from least clicked links.
# The sentences sampled from top clicked links are very_confusing
# ...

# %%
print("The average Flesch eading-ease Score of most clicked link sentences is:", sum(f_most_scores)/len(f_most_scores))
print("The average Flesch eading-ease Score of lest clicked link sentences is:", sum(f_least_scores)/len(f_least_scores))
if(sum(f_most_scores)/len(f_most_scores) > sum(f_least_scores)/len(f_least_scores)):
    print("The most clicked link sentences are easier to read.")
    print("In another words, people tend to click a link where the sentence is easier to read.")
else:
    print("The most clicked link sentences are more difficult to read.")
# Out:
# The average Flesch eading-ease Score of most clicked link sentences is: 26.80221474058751
# The average Flesch eading-ease Score of lest clicked link sentences is: 7.892262719669543
# The most clicked link sentences are easier to read.
# In another words, people tend to click a link where the sentence is easier to read.

# %%
def calculate_readability_interval(sample_rate, threshold_1, threshold_2):
    """
    Input:
        sample_rate: the proportion that is going to be sampled of all articles
        threshold_1: lower bound proportion
        threshold_2: upper bound proportion
    What it does:
        for every article sampled, for every link in it
        first find the maximum number of link click
        then use threshold_1*max_num and threshold_2*max_num as threshold
        to find the links whose click numbers are in the interval
        get their sentences and calculate the readability
    Output:
        f_score: the Flesch reading-ease Score of links sentences in the desired interval
    """
    sampled_art = []
    for key in page_link_dict:
        random_number = random.uniform(0, 1)
        if(random_number < sample_rate and plain_txt_dict.get(key.replace('.htm',''))!=None):
            sampled_art.append(key)

    sentences = []
    for art in sampled_art:
        text = plain_txt_dict[art.replace('.htm','')]
        max_count = 0

        judge = 0
        for article_count_list in page_link_dict.get(art):
            if(article_count_list[1]>1):
                judge = 1
        if(judge==0):
            continue
        # find the maximum click number and calculate thresholds
        for article_count_list in page_link_dict.get(art):
            if(article_count_list[1]>max_count):
                max_count = article_count_list[1]
        threshold_up = threshold_2 * max_count
        threshold_down = threshold_1 * max_count
        # make the last interval to be closed both sides
        if(threshold_2==1):
            threshold_up += 1
        # find sentences according to thresholds
        for article_count_list in page_link_dict.get(art):
            if(article_count_list[1]<threshold_up and article_count_list[1]>=threshold_down):
                temp_sent = find_sentence(text, article_count_list[0].replace('_',' '))
                if(len(temp_sent)!=0):
                    for sent in temp_sent:
                        sentences.append(sent)
    # print how many sentences are sampled and calculate readability
    # print(len(sentences), "sentences sampled from range {0:02d}% to {1:02d}%.".format(int(threshold_1*100), int(threshold_2*100)))
    f_sentences = flatten_sentences_list(sentences)
    r = Readability(f_sentences)
    f = r.flesch()
    # print("The Flesch reading-ease Score is: ", f.score)
    # print("The sentences sampled from this range are", f.ease)
    # print("It is suitable for", f.grade_levels)
    f_score = f.score
    return f_score

# %%
# From 0 to 1, set 10 intervals: (0,0.1], (0.1,0.2] ... [0.9,1]
# For each interval sample and calculate 10 times
intervals_lists = []
for i in range(10):
    itv_list = []
    for j in range(10):
        f_score = calculate_readability_interval(sample_rate=0.1, threshold_1=i/10, threshold_2=(i+1)/10)
        itv_list.append(f_score)
    intervals_lists.append(itv_list)

# %%
# the average Flesch reading-ease Score for each interval
average_list = []
for list_i in intervals_lists:
    average = sum(list_i)/len(list_i)
    average_list.append(average)

# %%
# plot the results
xlabel = ['[0,0.1)', '[0.1,0.2)', '[0.2,0.3)',
          '[0.3,0.4)', '[0.4,0.5)', '[0.5,0.6)',
          '[0.6,0.7)', '[0.7,0.8)', '[0.8,0.9)', '[0.9,1]']
range_list_min = []
range_list_max = []
for list_i in intervals_lists:
    temp_max = np.std(list_i) + sum(list_i)/len(list_i)
    temp_min = -np.std(list_i) + sum(list_i)/len(list_i)
    range_list_min.append(temp_min)
    range_list_max.append(temp_max)
error_list = [range_list_min, range_list_max]
plt.errorbar(xlabel, average_list)
plt.xticks(rotation=45)
plt.ylabel("Flesch reading-ease Score")
plt.xlabel("Proportion to most clicked links in each articles")
plt.grid(drawstyle="steps")
plt.title("Distribution of sentence readability to link click numbers")
# Out:
# Text(0.5, 1.0, 'Distribution of sentence readability to link click numbers')

# %% [markdown]
# In the above plot, the x-axis is the frequency interval of the clicking links. [0, 0.1) means the clicking time of those links is between 0 to 10% of the maximum clicking frequency. From the results, we discover that for those links which have a higher clicking numbers, they possess a higher readability score, which indicates that the sentences including those links are much easier for human to understand. The readability truly has an impact on people’s clicking behavior.

# %% [markdown]
# We consider that there are two possible reasons to explain the phenomenon.

# %% [markdown]
# The first one is that people do not simply skip all contents in the HTML page and only focus on the labeled links in the webpage. The fact is that players still scan the text on the page and then select their next link to click. For those links which have a lower readability score, in other words for those paragraphs and sentences which are more difficult to figure out, people have to pay more energy and time to read it and understand the content. As a consequence, during the game playing, people are reluctant to read those sentences with lower readability score. They prefer to only concentrate on sentences that are comfortable to read. And this explanation could lead to the results in previous diagram.

# %% [markdown]
# The second reason is about the position of the link. As we know, every Wikipedia page follows a general structure. For instance, at the beginning, there is an abstract of whole contents on the webpage. In the next several sections, Wikipedia will introduce relevant information one by one in details according to the sequence defined in **Contents**. Therefore, we put forward a hypothesis that people tend to only read the contents at the front of the page, for instance, the abstract of the whole HTML page. And we have also calculated the readability of abstract part and the detailed information introduction after the abstract. The readability score of abstracts is averagely higher than the other parts since it does not include plenty of professional terms and explanation.

# %% [markdown]
# As a consequence, we will continue to study on the question whether the position of links influence people’s clicking during the game.

# %% [markdown]
# ## Position Analysis

# %% [markdown]
# We will continue our research on the position of links. Put yourself in the players’ shoes, when you do the searching, would you read the articles carefully and thoroughly from the first line to the last line, or scan the article quickly and get the key point as fast as you can? It might be natural to do it in the latter way. If so, in the Wikispeedia game, people may have a tendency to click the links that shown earlier in an article. Is it really the case? In this section, we are going to investigate whether link position plays a role when people do the navigation.

# %% [markdown]
# ### What is the average position over all links in the HTML page?
#
# In this part, we first check the position of links that people clicked most and the average position of links. We use the index of desired link divided by the length of article to represent the link position.

# %% [markdown]
# In order to find the relationship of link position and click frequency. Let’s find the average position of the links first.

# %%
# build a dictionary page_link_dict_pos
# whose keys are article names
#       values are dictionaries
#                  each dictionary contains the key: the link occurred
#                                               value: the position of it(length proportion)
HTML_folder_path = '../dataset/wikispeedia_articles_html/wpcd/wp'
page_link_dict_pos = {}
for folder_name in os.listdir(HTML_folder_path):
    HTML_page_folder_path = os.path.join(HTML_folder_path, folder_name)
    if folder_name != 'index':
        for page_name in os.listdir(HTML_page_folder_path):
            if 'htm' in page_name:
                link_list = {}
                page_path = os.path.join(HTML_page_folder_path, page_name)
                # read the html file and search the href links
                with open(page_path, 'r', encoding='ISO-8859-1') as f:
                    content = f.read()
                    bsObj = BeautifulSoup(content, 'html.parser')
                    # Find all links with <a> and href attribute
                    t1 = bsObj.find_all(name='a',attrs={"href":re.compile(r'^((?!png|jpg).)*.htm*((?!png|jpg).)*$')})
                    for link in t1:
                        if 'href' in link.attrs.keys() and 'title' in link.attrs.keys():
                            temp_str = urllib.parse.unquote(link['href'])
                            htm_index = temp_str.rfind('.htm')
                            line_index = len(temp_str)
                            while(True):
                                line_index = temp_str[:line_index].rfind('/')
                                if line_index <= htm_index:
                                    break
                            link_name = temp_str[line_index+1:htm_index]
                            if link_name in article_list and link_name not in link_list:
                                link_list[link_name] = content.index(link['href']) / len(content)
                    # Find all links with <link> and href attribute
                    t2 = bsObj.find_all(name='link',attrs={"href":re.compile(r'^((?!png|jpg).)*.htm*((?!png|jpg).)*$')})
                    for link in t2:
                        if 'href' in link.attrs.keys():
                            temp_str = urllib.parse.unquote(link['href'])
                            htm_index = temp_str.rfind('.htm')
                            line_index = len(temp_str)
                            while(True):
                                line_index = temp_str[:line_index].rfind('/')
                                if line_index <= htm_index:
                                    break
                            link_name = temp_str[line_index+1:htm_index]

                            if link_name in article_list and link_name not in link_list:
                                link_list[link_name] = content.index(link['href']) / len(content)
                page_link_dict_pos[page_name] = link_list

# %%
# merge page_link_dict and page_link_dict_pos
for key in page_link_dict:
    for article_count_list in page_link_dict.get(key):
        pos = page_link_dict_pos.get(key).get(article_count_list[0])
        article_count_list.append(pos)

# %% [markdown]
# It’s important to define the link position. We decide to use the word index divided by the article length as the representative of link position. For example, if a link is the 20th word in a 200-word-article, its position is defined as 20/200 equals to 0.1. Therefore, the range of link position is (0,1]. Through this method, we get rid of the various length of HTML pages.
# Then, we iterate through all the links in the HTML files and calculate the average link position. It turns out that the average link position is 0.4554 and the median is 0.4296. It shows that the links are not strictly, but almost uniformly distributed from beginning to end.

# %%
# check the average link position of all links in each article
positions = []
for key in page_link_dict:
    for article_count_list in page_link_dict.get(key):
        positions.append(article_count_list[2])
print("The link average position is at the length {0:04f} of the whole length.".format(sum(positions)/len(positions)))
print("And the median is: ", statistics.median(positions))
# Out:
# The link average position is at the length 0.455356 of the whole length.
# And the median is:  0.429627848253472

# %% [markdown]
# ### What is the average position of higher clicking frequency links in the HTML page?

# %%
# check the average link position of most clicked link in each article
positions = []
for key in page_link_dict:
    max_count = 0
    for article_count_list in page_link_dict.get(key):
        if(article_count_list[1]>max_count):
            max_count = article_count_list[1]
    if(max_count==0):
        continue
    for article_count_list in page_link_dict.get(key):
        if(article_count_list[1]==max_count):
            positions.append(article_count_list[2])
print("For each article, the most clicked link is at the length {0:04f} of the whole length.".format(sum(positions)/len(positions)))
# Out:
# For each article, the most clicked link is at the length 0.332139 of the whole length.

# %% [markdown]
# After getting a glimpse of the whole links, how about the links that are clicked most in each article? For each article, we find the link that the users clicked the most and calculate the average position of it. The average value turns out to be 0.3321 and shows a shift from the average value of all links. It seems that the most popular links shown earlier in the articles. Let’s dig deeper in the next subsection.

# %% [markdown]
# ### What is the distribution of position over Top n% clicked links in HTML page?
#
# Then we are going to check tbe distribution of link position over top n% clicked links and see if there exists relationship of link position and user click tendency.

# %% [markdown]
# To check the distribution of most clicked links’ position, we draw a bar chart as shown. The darkest bar shows the distribution (in percentage) of top 10% clicked links’ position in five intervals. The middle is the top 50% and the lightest bar shows the distribution over all links.

# %%
def find_distri_mostclicklink_pos(ratio, num_interval):
    """
    Input:
        ratio: Find the top clicked links by this ratio
        num_interval: number of intervals
        (e.g if 5, then divide 0-1(position proportion to whole length) to 5 intervals: 0-0.2, 0.2-0.4 ...)
    Output:
        interval_count_percen: length of num_interval, percentage of top clicked links layed in intervals
    """
    # get the desired positions
    positions = []
    for key in page_link_dict:
        max_count = 0
        for article_count_list in page_link_dict.get(key):
            if(article_count_list[1]>max_count):
                max_count = article_count_list[1]
        if(max_count==0):
            continue
        threshold = (1-ratio)*max_count
        for article_count_list in page_link_dict.get(key):
            if(article_count_list[1]>=threshold):
                positions.append(article_count_list[2])
    # find the percentage
    interval_length = 1/num_interval
    interval_count = []
    for i in range(num_interval):
        count = len(list(x for x in positions if i/10 <= x <= (i+1)/10))
        interval_count.append(count)
    sum_count = sum(interval_count)
    interval_count_percen = [100*e/sum_count for e in interval_count]
    return interval_count_percen

# %%
# visualize the result
# take three categories: 10% top clicked links, 50% top clicked links and all links
perc_1 = find_distri_mostclicklink_pos(0.1, 5)
perc_2 = find_distri_mostclicklink_pos(0.5, 5)
perc_3 = find_distri_mostclicklink_pos(1, 5)
index = np.arange(len(perc_1))
width = 0.25
xticks = ['0-0.2','0.2-0.4', '0.4-0.6','0.6-0.8','0.8-1']
bar_1 = plt.bar(index, perc_1, width, color = "#032147")
bar_2 = plt.bar(index+width, perc_2, width, color = "#0156BD")
bar_3 = plt.bar(index+width+width, perc_3, width, color = "#61A4F7")
plt.xlabel("Proportion of link position to the whole length of the article")
plt.ylabel("Percentage")
plt.title("Distribution of link position over click numbers")
plt.xticks(index+2*width/2, xticks)
plt.legend([bar_1, bar_2, bar_3], ["top clicked 10%", "top clicked 50%", "top clicked 100%"])
plt.show()

# %% [markdown]
# The bar chart tells us a lot of information. First, position 0.2 to 0.4 has the most links among all the intervals. We may infer that: In an article, after an introduction, this interval is usually the most divergent or connective to other articles (generally, this part is close to the abstract section in Wikipedia). Second, when comparing the top 10%, 50% and 100% top clicked links, top 10% and 50% have larger distribution in position 0 to 0.2 and 0.2 to 0.4, while for the rest of the position intervals has smaller distribution. What’s more, in position 0.2 to 0.4, the top clicked links show a significant increasement as the popularity grows.

# %% [markdown]
# Therefore, we draw to the conclusion that people do have a tendency to the link position in the webpages when doing the navigation. People tend to click on links that occur earlier in articles (most from relative positive 0.2 to 0.4), for instance in the abstract part of the Wikipedia. The result goes along with our intuition. During the game playing, people do not have much time to scan the whole HTML contents. They instead focus on the first several lines of the webpage and read the corresponding contents to decide the next clicking article. The outcome in position analysis also strengthens the conclusion in the readability section. At the beginning of the Wikipedia, there do not include plenty of professional terms or equations, and when people prefer to select links in this section, the readability score of those links will then become larger as readability analysis shows.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# From above analysis, we could answer our initial title question preliminarily. During the word navigation, human is influenced by various general clicking patterns. We draw to the conclusion that people always use the geographical and national information to help them get closer to the target word. Players also tend to skip or look carelessly on sentences which are difficult to figure out. As the consequence, links in specialized or professional knowledge paragraph will not be taken into account during the navigation procedure. Besides, people are always attracted by links which lie at the front of HTML page and reluctant to scan the  lower half of the webpage. All those internal and external factors make the path finishing by human a bit inflexible and seems stereotypical.
# However, human still remains their unparalleled creativity while finding the target word from the source. In LDA analysis, though different people may possess the similar topic transition in the article selection path in parts of tasks, nevertheless, given the source and destination word, it is still impossible to predict on the topic variation between source and target. Distinct people remain their own unique ideas toward the connection of two words, even when their linking tasks are same. Those fantastic thoughts make everyone separate from others.
