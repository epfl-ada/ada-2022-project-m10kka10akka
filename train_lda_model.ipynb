# %%
import argparse
import re
import os
import warnings
warnings.filterwarnings('ignore')
import gensim
from gensim import corpora
from gensim.models import CoherenceModel
import time
from pprint import pprint

# %%
# Load preprocessed data
data_words = []
data_words_path = "data_words.txt"

with open(data_words_path, "r", encoding = 'utf-8') as f:
    file = f.readlines()
for line in file:
    words = line.split("', '")
    data_words.append(words)    
del file

# %%
# Create dictionary
id2word = corpora.Dictionary(data_words)
id2word.filter_extremes(no_below=5, no_above=0.5)
# Create corpus
corpus = [id2word.doc2bow(text) for text in data_words]

# %%
# Calculate topic diversity score, score is between 0-1
def topic_diversity(lda_model, t):
    topics = str(lda_model.print_topics(t))
    topics = re.sub(r'\W|1|2|3|4|5|6|7|8|9', "", topics)
    topics = re.sub(r'0', " ", topics)
    topiclist = topics.split(' ')
    topiclist = [x for x in topiclist if x != '']
    topicset = set(topiclist)
    diversity_score = len(topicset)/len(topiclist)
    return diversity_score

# %%
# Build LDA model, only keeping the results
def build_lda_model(corpus, dictionary, topic, alpha, beta, seed):
    lda_model = gensim.models.LdaModel(corpus=corpus,
                                       id2word=dictionary,
                                       num_topics=topic, 
                                       random_state=seed,
                                       chunksize=100,
                                       passes=10,
                                       alpha=alpha,
                                       eta=beta)
    pprint(lda_model.print_topics())

    coherence_model_lda = CoherenceModel(model=lda_model, texts=data_words, \
                          dictionary=id2word, coherence='c_v')
    coherence_score = '%.3f'%coherence_model_lda.get_coherence()
    diversity_score = '%.3f'%topic_diversity(lda_model, topic)
    
    model_name = 'topic_'+str(topic)+'_alpha_'+str(alpha)+'_beta_'+str(beta)+'_coh_'+str(coherence_score)\
                   +'_div_'+str(diversity_score)
    # make sure the folder already exists
    model_path = str(model_name) + ".txt"
    lda_model.save(model_path)
    # note that only the name and scores of the model is saved into a txt file here to save memory
    f = open(model_path, 'w')
    f.write(model_name)
    f.close()
    return coherence_score, diversity_score

# %%
t = 30
a = 0.1
b = 0.1
s = 42
print(build_lda_model(corpus=corpus, dictionary=id2word, topic=t, alpha=a, beta=b, seed=s))
# Out:
# [(4,
#   '0.097*"language" + 0.044*"dialect" + 0.038*"spanish" + 0.035*"dutch" + '
#   '0.035*"zuid_gelder" + 0.031*"speak" + 0.021*"word" + 0.018*"english" + '
#   '0.013*"netherland" + 0.012*"french"'),
#  (26,
#   '0.015*"reverend" + 0.000*"wilson" + 0.000*"postman" + 0.000*"bryan" + '
#   '0.000*"primus" + 0.000*"menlo_park" + 0.000*"irishman" + 0.000*"arle" + '
#   '0.000*"boone" + 0.000*"niagara_fall"'),
#  (25,
#   '0.009*"bear" + 0.009*"family" + 0.008*"death" + 0.008*"die" + 0.007*"write" '
#   '+ 0.007*"child" + 0.006*"return" + 0.005*"young" + 0.005*"school" + '
#   '0.005*"say"'),
#  (18,
#   '0.235*"island" + 0.048*"shark" + 0.040*"wale" + 0.040*"australian" + '
#   '0.033*"tiger" + 0.022*"extinct" + 0.015*"wombat" + 0.013*"australia" + '
#   '0.013*"tonga" + 0.012*"woodpecker"'),
#  (8,
#   '0.016*"octavian" + 0.004*"mark_antony" + 0.002*"cleopatra" + '
#   '0.002*"caesarion" + 0.001*"octavia_minor" + 0.001*"ides_march" + '
#   '0.000*"gaius_julius" + 0.000*"antony_cleopatra" + 0.000*"triumvirate" + '
#   '0.000*"gen"'),
#  (10,
#   '0.051*"church" + 0.022*"religious" + 0.014*"jewish" + 0.013*"catholic" + '
#   '0.013*"christian" + 0.012*"religion" + 0.012*"faith" + 0.009*"protestant" + '
#   '0.008*"bishop" + 0.007*"teaching"'),
#  (29,
#   '0.032*"city" + 0.014*"river" + 0.008*"building" + 0.008*"university" + '
#   '0.008*"water" + 0.008*"centre" + 0.008*"locate" + 0.007*"park" + '
#   '0.007*"build" + 0.007*"school"'),
#  (15,
#   '0.077*"silver" + 0.060*"coin" + 0.060*"gold" + 0.049*"currency" + '
#   '0.028*"value" + 0.023*"absorption" + 0.022*"note" + 0.017*"mint" + '
#   '0.016*"denomination" + 0.016*"federal_reserve"'),
#  (12,
#   '0.020*"water" + 0.012*"produce" + 0.010*"process" + 0.009*"metal" + '
#   '0.009*"material" + 0.007*"element" + 0.006*"compound" + 0.006*"production" '
#   '+ 0.006*"product" + 0.005*"chemical"'),
#  (6,
#   '0.021*"government" + 0.015*"member" + 0.012*"party" + 0.011*"vote" + '
#   '0.011*"election" + 0.010*"power" + 0.010*"united_state" + 0.009*"political" '
#   '+ 0.009*"president" + 0.009*"right"'),
#  (28,
#   '0.018*"theory" + 0.008*"system" + 0.008*"science" + 0.008*"study" + '
#   '0.007*"field" + 0.006*"function" + 0.006*"property" + 0.006*"define" + '
#   '0.006*"energy" + 0.006*"scientific"'),
#  (0,
#   '0.071*"spectrum" + 0.017*"earth" + 0.011*"planet" + 0.010*"surface" + '
#   '0.010*"star" + 0.009*"light" + 0.008*"space" + 0.007*"disk" + 0.007*"orbit" '
#   '+ 0.007*"device"'),
#  (11,
#   '0.015*"software" + 0.012*"system" + 0.012*"release" + 0.010*"program" + '
#   '0.010*"sinclair" + 0.010*"computer" + 0.009*"machine" + 0.009*"user" + '
#   '0.009*"window" + 0.008*"version"'),
#  (22,
#   '0.014*"cell" + 0.012*"disease" + 0.011*"vitamin" + 0.010*"human" + '
#   '0.008*"study" + 0.008*"protein" + 0.007*"increase" + 0.007*"treatment" + '
#   '0.006*"patient" + 0.006*"occur"'),
#  (17,
#   '0.008*"say" + 0.006*"go" + 0.006*"show" + 0.006*"kill" + 0.005*"appear" + '
#   '0.005*"see" + 0.005*"report" + 0.004*"claim" + 0.004*"believe" + '
#   '0.004*"black"'),
#  (19,
#   '0.011*"text" + 0.009*"zoroaster" + 0.008*"date" + 0.008*"word" + '
#   '0.008*"ancient" + 0.007*"modern" + 0.007*"write" + 0.006*"accord" + '
#   '0.006*"historical" + 0.006*"tradition"'),
#  (9,
#   '0.038*"game" + 0.028*"player" + 0.022*"team" + 0.022*"play" + 0.012*"ball" '
#   '+ 0.010*"season" + 0.008*"match" + 0.008*"final" + 0.008*"sport" + '
#   '0.007*"race"'),
#  (13,
#   '0.032*"film" + 0.021*"character" + 0.017*"story" + 0.016*"series" + '
#   '0.016*"book" + 0.014*"play" + 0.013*"write" + 0.013*"novel" + '
#   '0.012*"episode" + 0.008*"poem"'),
#  (24,
#   '0.120*"german" + 0.062*"russian" + 0.047*"soviet" + 0.046*"polish" + '
#   '0.023*"soviet_union" + 0.020*"jewish" + 0.016*"warsaw" + 0.014*"swedish" + '
#   '0.013*"hitler" + 0.012*"communist"'),
#  (21,
#   '0.024*"painting" + 0.023*"paint" + 0.020*"colour" + 0.020*"artist" + '
#   '0.019*"wood" + 0.016*"design" + 0.013*"style" + 0.012*"window" + '
#   '0.011*"image" + 0.010*"color"')]
# ('0.581', '0.917')
